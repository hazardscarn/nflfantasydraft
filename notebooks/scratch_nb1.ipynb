# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import pickle
import os

class FantasyFootballDraftAssistant:
    def __init__(self):
        self.df = None
        self.positions = {'QB': (1, 2), 'RB': (6, 9), 'WR': (5, 9), 'TE': (1, 2), 'K': (1, 1), 'DST': (1, 1)}
        self.starting_positions = {'QB': 1, 'RB': 2, 'WR': 3, 'TE': 1, 'K': 1, 'DST': 1, 'FLEX': 1}
        self.flex_positions = ['RB', 'WR', 'TE']
        self.q_table = {}
        self.alpha = 0.1  # Learning rate
        self.gamma = 0.9  # Discount factor
        self.epsilon = 0.1  # Exploration rate
        self.total_episodes = 0
        
    def load_data(self, file_path):
        self.df = pd.read_csv(file_path)
        self.df['ADP'] = pd.to_numeric(self.df['ADP'], errors='coerce')
        self.df = self.df.sort_values('ADP').reset_index(drop=True)
        self.players = self.df.to_dict('records')
        
    def get_state(self, team, round_num):
        return (tuple(sum(1 for p in team if p['pos'] == pos) for pos in self.positions.keys()), round_num)
    
    def get_actions(self, available_players, team, round_num):
        actions = []
        for player in available_players:
            pos = player['pos']
            pos_count = sum(1 for p in team if p['pos'] == pos)
            if pos_count < self.positions[pos][1] and (pos not in ['K', 'DST'] or round_num > 12):
                actions.append(player['player'])
        return actions
    
    def calculate_team_value(self, team):
        weekly_scores = []
        for week in range(1, 18):  # 17-week season
            available_players = [p for p in team if p['bye_week'] != week]
            starters = self.select_starters(available_players)
            week_score = sum(p['ppr_projection'] / 17 for p in starters)
            weekly_scores.append(week_score)
        
        total_score = sum(weekly_scores)
        bench_strength = sum(p['ppr_projection'] for p in team) - sum(p['ppr_projection'] for p in self.select_starters(team))
        return total_score + (bench_strength * 0.1)  # Adding some value for bench strength
    
    def select_starters(self, available_players):
        starters = []
        for pos, count in self.starting_positions.items():
            if pos == 'FLEX':
                flex_options = sorted([p for p in available_players if p['pos'] in self.flex_positions and p not in starters], 
                                      key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(flex_options[:count])
            else:
                pos_players = sorted([p for p in available_players if p['pos'] == pos and p not in starters], 
                                     key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(pos_players[:count])
        return starters
    
    def calculate_reward(self, team, player, round_num):
        team_value_before = self.calculate_team_value(team)
        new_team = team + [player]
        team_value_after = self.calculate_team_value(new_team)
        value_added = team_value_after - team_value_before
        
        adp_bonus = max(0, (200 - player['ADP']) / 10) if not np.isnan(player['ADP']) else 0
        round_penalty = max(0, round_num - 12) * 5 if player['pos'] in ['K', 'DST'] else 0
        
        # Encourage early RB and WR picks
        if round_num <= 2 and player['pos'] in ['RB', 'WR']:
            value_added *= 1.2
        
        return value_added + adp_bonus - round_penalty
   
    
    def recommend_players(self, team, available_players, round_num, num_recommendations=5):
        state = self.get_state(team, round_num)
        actions = self.get_actions(available_players, team, round_num)
        q_values = [(a, self.q_table.get((state, a), 0)) for a in actions]  # Change this line
        top_actions = sorted(q_values, key=lambda x: x[1], reverse=True)[:num_recommendations]
        return [(next(p for p in available_players if p['player'] == a), q) for a, q in top_actions]
    
    def simulate_draft(self, user_position, num_teams=12):
        teams = [[] for _ in range(num_teams)]
        available_players = self.players.copy()
        user_picks = []
        
        for round_num in range(1, 19):
            draft_order = range(num_teams) if round_num % 2 == 1 else reversed(range(num_teams))
            for pick_in_round, team_index in enumerate(draft_order):
                if team_index == user_position:
                    recommendations = self.recommend_players(teams[team_index], available_players, round_num)
                    user_picks.append(((round_num - 1) * num_teams + pick_in_round + 1, recommendations))
                    
                    if recommendations:
                        selected_player, _ = recommendations[0]
                        teams[team_index].append(selected_player)
                        available_players = [p for p in available_players if p['player'] != selected_player['player']]
                else:
                    # Other teams draft based on ADP
                    valid_players = [p for p in available_players if sum(1 for player in teams[team_index] if player['pos'] == p['pos']) < self.positions[p['pos']][1]]
                    if valid_players:
                        player = min(valid_players, key=lambda p: p['ADP'] if not np.isnan(p['ADP']) else float('inf'))
                        teams[team_index].append(player)
                        available_players = [p for p in available_players if p['player'] != player['player']]
        
        return user_picks, teams

    def train(self, num_episodes=10000, num_teams=12):
        start_episode = self.total_episodes
        for episode in range(start_episode, start_episode + num_episodes):
            if episode % 1000 == 0:
                print(f"Training episode {episode}/{start_episode + num_episodes}")
            
            teams = [[] for _ in range(num_teams)]
            available_players = self.players.copy()
            
            for round_num in range(1, 19):
                for team_index in range(num_teams):
                    state = self.get_state(teams[team_index], round_num)
                    actions = self.get_actions(available_players, teams[team_index], round_num)
                    
                    if not actions:
                        continue
                    
                    if np.random.uniform(0, 1) < self.epsilon:
                        action = np.random.choice(actions)
                    else:
                        q_values = [self.q_table.get((state, a), 0) for a in actions]  # Change this line
                        action = actions[np.argmax(q_values)]
                    
                    player = next(p for p in available_players if p['player'] == action)
                    reward = self.calculate_reward(teams[team_index], player, round_num)
                    teams[team_index].append(player)
                    available_players = [p for p in available_players if p['player'] != action]
                    
                    next_state = self.get_state(teams[team_index], round_num + 1)
                    
                    # Q-value update
                    max_future_q = max([self.q_table.get((next_state, a), 0) for a in self.get_actions(available_players, teams[team_index], round_num + 1)], default=0)
                    current_q = self.q_table.get((state, action), 0)  # Change this line
                    new_q = (1 - self.alpha) * current_q + self.alpha * (reward + self.gamma * max_future_q)
                    self.q_table[(state, action)] = new_q  # Change this line
        
        self.total_episodes += num_episodes
    
    def save_model(self, file_path):
        with open(file_path, 'wb') as f:
            pickle.dump((dict(self.q_table), self.total_episodes), f)  # Change this line
        print(f"Model saved to {file_path}")
    
    def load_model(self, file_path):
        with open(file_path, 'rb') as f:
            loaded_q_table, self.total_episodes = pickle.load(f)
            self.q_table = loaded_q_table  # Change this line
        print(f"Model loaded from {file_path}. Total episodes: {self.total_episodes}")

# %%
# Usage and testing
assistant = FantasyFootballDraftAssistant()
assistant.load_data('data//cbs_fantasy_projection_master.csv')

model_file = 'data//fantasy_football_model.pkl'

# Check if a saved model exists
if os.path.exists(model_file):
    assistant.load_model(model_file)
    print("Continuing training from saved model...")
else:
    print("Starting new training...")

# Train for 10,000 episodes
print("Training the model...")
assistant.train(num_episodes=50000)

# Save the model after training
assistant.save_model(model_file)
# Out:
# Model loaded from data//fantasy_football_model.pkl. Total episodes: 60000
# Continuing training from saved model...
# Training the model...
# Training episode 60000/110000
# Training episode 61000/110000
# Training episode 62000/110000
# Training episode 63000/110000
# Training episode 64000/110000
# Training episode 65000/110000
# Training episode 66000/110000
# Training episode 67000/110000
# Training episode 68000/110000
# Training episode 69000/110000
# Training episode 70000/110000
# Training episode 71000/110000
# Training episode 72000/110000
# Training episode 73000/110000
# Training episode 74000/110000
# Training episode 75000/110000
# Training episode 76000/110000
# Training episode 77000/110000
# Training episode 78000/110000
# Training episode 79000/110000
# Training episode 80000/110000
# Training episode 81000/110000
# Training episode 82000/110000
# Training episode 83000/110000
# Training episode 84000/110000
# Training episode 85000/110000
# Training episode 86000/110000
# Training episode 87000/110000
# Training episode 88000/110000
# Training episode 89000/110000
# Training episode 90000/110000
# Training episode 91000/110000
# Training episode 92000/110000
# Training episode 93000/110000
# Training episode 94000/110000
# Training episode 95000/110000
# Training episode 96000/110000
# Training episode 97000/110000
# Training episode 98000/110000
# Training episode 99000/110000
# Training episode 100000/110000
# Training episode 101000/110000
# Training episode 102000/110000
# Training episode 103000/110000
# Training episode 104000/110000
# Training episode 105000/110000
# Training episode 106000/110000
# Training episode 107000/110000
# Training episode 108000/110000
# Training episode 109000/110000
# Model saved to data//fantasy_football_model.pkl

# %%
user_position=7
print(f"\nSimulating a draft for a user in position {user_position + 1}...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=user_position)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[user_position]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 8...
#
# Recommendations for your picks:
#
# Pick 8:
#   1. Amon-Ra St. Brown (WR) - Q-value: 258.90, ADP: 6.80
#   2. A.J. Brown (WR) - Q-value: 256.85, ADP: 10.20
#   3. Puka Nacua (WR) - Q-value: 256.71, ADP: 12.40
#   4. Marvin Harrison Jr. (WR) - Q-value: 255.14, ADP: 18.00
#   5. Garrett Wilson (WR) - Q-value: 253.97, ADP: 13.60
#
# Pick 17:
#   1. Davante Adams (WR) - Q-value: 241.69, ADP: 18.40
#   2. Chris Olave (WR) - Q-value: 240.57, ADP: 23.40
#   3. Drake London (WR) - Q-value: 239.99, ADP: 25.20
#   4. Nico Collins (WR) - Q-value: 239.81, ADP: 32.80
#   5. Deebo Samuel (WR) - Q-value: 239.52, ADP: 33.00
#
# Pick 32:
#   1. Lamar Jackson (QB) - Q-value: 224.49, ADP: 37.60
#   2. C.J. Stroud (QB) - Q-value: 222.15, ADP: 47.60
#   3. Joe Burrow (QB) - Q-value: 221.51, ADP: 60.00
#   4. Anthony Richardson (QB) - Q-value: 221.18, ADP: 53.40
#   5. Dak Prescott (QB) - Q-value: 220.78, ADP: 68.40
#
# Pick 41:
#   1. Mark Andrews (TE) - Q-value: 202.84, ADP: 43.60
#   2. Trey McBride (TE) - Q-value: 201.75, ADP: 46.60
#   3. Dalton Kincaid (TE) - Q-value: 199.98, ADP: 52.20
#   4. George Kittle (TE) - Q-value: 198.63, ADP: 59.00
#   5. Evan Engram (TE) - Q-value: 197.90, ADP: 65.60
#
# Pick 56:
#   1. Evan Engram (TE) - Q-value: 193.16, ADP: 65.60
#   2. Kyle Pitts (TE) - Q-value: 192.42, ADP: 61.20
#   3. David Njoku (TE) - Q-value: 191.50, ADP: 82.40
#   4. Jake Ferguson (TE) - Q-value: 189.90, ADP: 87.60
#   5. Brock Bowers (TE) - Q-value: 187.01, ADP: 102.40
#
# Pick 65:
#   1. Christian Kirk (WR) - Q-value: 182.42, ADP: 71.20
#   2. Keenan Allen (WR) - Q-value: 181.91, ADP: 70.00
#   3. Chris Godwin (WR) - Q-value: 181.53, ADP: 76.00
#   4. Calvin Ridley (WR) - Q-value: 181.50, ADP: 75.20
#   5. Terry McLaurin (WR) - Q-value: 180.65, ADP: 74.80
#
# Pick 80:
#   1. Jayden Daniels (QB) - Q-value: 173.60, ADP: 109.40
#   2. Brock Purdy (QB) - Q-value: 173.30, ADP: 96.20
#   3. Jared Goff (QB) - Q-value: 173.16, ADP: 118.00
#   4. Tua Tagovailoa (QB) - Q-value: 171.51, ADP: 115.60
#   5. Trevor Lawrence (QB) - Q-value: 171.13, ADP: 133.20
#
# Pick 89:
#   1. Brian Robinson Jr. (RB) - Q-value: 139.71, ADP: 97.40
#   2. Jerome Ford (RB) - Q-value: 139.62, ADP: 124.60
#   3. Austin Ekeler (RB) - Q-value: 139.58, ADP: 89.80
#   4. Jaleel McLaughlin (RB) - Q-value: 138.77, ADP: 174.40
#   5. Zack Moss (RB) - Q-value: 138.27, ADP: 89.00
#
# Pick 104:
#   1. Trey Benson (RB) - Q-value: 103.51, ADP: 121.80
#   2. Tyjae Spears (RB) - Q-value: 103.50, ADP: 103.20
#   3. Gus Edwards (RB) - Q-value: 103.13, ADP: 112.20
#   4. J.K. Dobbins (RB) - Q-value: 102.95, ADP: 133.60
#   5. Chase Brown (RB) - Q-value: 102.70, ADP: 120.80
#
# Pick 113:
#   1. Courtland Sutton (WR) - Q-value: 81.40, ADP: 119.80
#   2. Brian Thomas Jr. (WR) - Q-value: 81.12, ADP: 124.00
#   3. Jameson Williams (WR) - Q-value: 80.72, ADP: 119.00
#   4. Khalil Shakir (WR) - Q-value: 80.54, ADP: 139.60
#   5. Gus Edwards (RB) - Q-value: 80.51, ADP: 112.20
#
# Pick 128:
#   1. Khalil Shakir (WR) - Q-value: 68.81, ADP: 139.60
#   2. Tyler Lockett (WR) - Q-value: 68.63, ADP: 131.20
#   3. Mike Williams (WR) - Q-value: 68.62, ADP: 143.80
#   4. Romeo Doubs (WR) - Q-value: 68.34, ADP: 142.60
#   5. Curtis Samuel (WR) - Q-value: 68.26, ADP: 136.20
#
# Pick 137:
#   1. Rico Dowdle (RB) - Q-value: 58.74, ADP: 159.60
#   2. Chuba Hubbard (RB) - Q-value: 58.63, ADP: 150.80
#   3. Ty Chandler (RB) - Q-value: 57.63, ADP: 161.80
#   4. Tyler Allgeier (RB) - Q-value: 57.44, ADP: 160.80
#   5. MarShawn Lloyd (RB) - Q-value: 57.31, ADP: 163.60
#
# Pick 152:
#   1. PHI (DST) - Q-value: 44.83, ADP: 175.00
#   2. CIN (DST) - Q-value: 44.71, ADP: 165.00
#   3. MIN (DST) - Q-value: 43.65, ADP: 212.00
#   4. TB (DST) - Q-value: 43.58, ADP: 229.00
#   5. CHI (DST) - Q-value: 43.49, ADP: 178.00
#
# Pick 161:
#   1. Keaton Mitchell (RB) - Q-value: 22.18, ADP: 225.80
#   2. Kendre Miller (RB) - Q-value: 22.12, ADP: 178.40
#   3. Miles Sanders (RB) - Q-value: 22.05, ADP: 252.00
#   4. Ameer Abdullah (RB) - Q-value: 21.98, ADP: 404.00
#   5. Antonio Gibson (RB) - Q-value: 21.94, ADP: 170.40
#
# Pick 176:
#   1. Jahan Dotson (WR) - Q-value: 11.06, ADP: 187.00
#   2. Greg Dortch (WR) - Q-value: 10.99, ADP: 272.00
#   3. Samaje Perine (RB) - Q-value: 10.88, ADP: 280.00
#   4. Roschon Johnson (RB) - Q-value: 10.81, ADP: 216.30
#   5. Kendrick Bourne (WR) - Q-value: 10.80, ADP: 279.00
#
# Pick 185:
#   1. Roman Wilson (WR) - Q-value: 3.72, ADP: 192.50
#   2. Carson Steele (RB) - Q-value: 3.60, ADP: 709.00
#   3. Kendrick Bourne (WR) - Q-value: 3.41, ADP: 279.00
#   4. D'Onta Foreman (RB) - Q-value: 3.34, ADP: 242.50
#   5. Wan'Dale Robinson (WR) - Q-value: 3.32, ADP: 216.50
#
# Pick 200:
#   1. Carson Steele (RB) - Q-value: 2.44, ADP: 709.00
#   2. Kendrick Bourne (WR) - Q-value: 2.01, ADP: 279.00
#   3. Wan'Dale Robinson (WR) - Q-value: 1.99, ADP: 216.50
#   4. D'Onta Foreman (RB) - Q-value: 1.78, ADP: 242.50
#   5. Tim Patrick (WR) - Q-value: 1.68, ADP: 356.00
#
# Pick 209:
#   1. D'Onta Foreman (RB) - Q-value: 0.94, ADP: 242.50
#   2. Darius Slayton (WR) - Q-value: 0.85, ADP: 299.50
#   3. DJ Chark (WR) - Q-value: 0.85, ADP: 311.30
#   4. A.T. Perry (WR) - Q-value: 0.84, ADP: 356.70
#   5. Rashod Bateman (WR) - Q-value: 0.80, ADP: 219.00
#
# Your team:
# Amon-Ra St. Brown (WR) - ADP: 6.80, Projection: 18.74
# Davante Adams (WR) - ADP: 18.40, Projection: 15.29
# Lamar Jackson (QB) - ADP: 37.60, Projection: 23.27
# Mark Andrews (TE) - ADP: 43.60, Projection: 12.76
# Evan Engram (TE) - ADP: 65.60, Projection: 12.09
# Christian Kirk (WR) - ADP: 71.20, Projection: 12.61
# Jayden Daniels (QB) - ADP: 109.40, Projection: 20.35
# Brian Robinson Jr. (RB) - ADP: 97.40, Projection: 11.35
# Trey Benson (RB) - ADP: 121.80, Projection: 8.69
# Courtland Sutton (WR) - ADP: 119.80, Projection: 11.11
# Khalil Shakir (WR) - ADP: 139.60, Projection: 10.48
# Rico Dowdle (RB) - ADP: 159.60, Projection: 9.24
# PHI (DST) - ADP: 175.00, Projection: 11.49
# Keaton Mitchell (RB) - ADP: 225.80, Projection: 6.05
# Jahan Dotson (WR) - ADP: 187.00, Projection: 8.98
# Roman Wilson (WR) - ADP: 192.50, Projection: 7.78
# Carson Steele (RB) - ADP: 709.00, Projection: 10.99
# D'Onta Foreman (RB) - ADP: 242.50, Projection: 8.71
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 2, 'K': 0, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 9, 'WR': 4, 'TE': 1, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 226.09
# Team 2: 220.63
# Team 3: 214.04
# Team 4: 220.45
# Team 5: 211.24
# Team 6: 220.06
# Team 7: 223.16
# Team 8: 219.97
# Team 9: 216.97
# Team 10: 217.80
# Team 11: 208.20
# Team 12: 217.10

# %%
user_position=0
print(f"\nSimulating a draft for a user in position {user_position}...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=user_position)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[user_position]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 0...
#
# Recommendations for your picks:
#
# Pick 1:
#   1. CeeDee Lamb (WR) - Q-value: 257.48, ADP: 2.00
#   2. Tyreek Hill (WR) - Q-value: 255.71, ADP: 3.20
#   3. Amon-Ra St. Brown (WR) - Q-value: 254.56, ADP: 6.80
#   4. Justin Jefferson (WR) - Q-value: 254.08, ADP: 6.00
#   5. Ja'Marr Chase (WR) - Q-value: 252.79, ADP: 5.80
#
# Pick 24:
#   1. Drake London (WR) - Q-value: 235.08, ADP: 25.20
#   2. Nico Collins (WR) - Q-value: 234.90, ADP: 32.80
#   3. Deebo Samuel (WR) - Q-value: 234.61, ADP: 33.00
#   4. Mike Evans (WR) - Q-value: 234.34, ADP: 30.80
#   5. Cooper Kupp (WR) - Q-value: 234.11, ADP: 38.20
#
# Pick 25:
#   1. Jalen Hurts (QB) - Q-value: 223.78, ADP: 31.80
#   2. Josh Allen (QB) - Q-value: 223.31, ADP: 26.20
#   3. Patrick Mahomes (QB) - Q-value: 221.06, ADP: 29.60
#   4. Lamar Jackson (QB) - Q-value: 219.69, ADP: 37.60
#   5. C.J. Stroud (QB) - Q-value: 217.10, ADP: 47.60
#
# Pick 48:
#   1. George Kittle (TE) - Q-value: 196.57, ADP: 59.00
#   2. David Njoku (TE) - Q-value: 194.76, ADP: 82.40
#   3. Brock Bowers (TE) - Q-value: 190.65, ADP: 102.40
#   4. T.J. Hockenson (TE) - Q-value: 189.35, ADP: 116.20
#   5. Dalton Schultz (TE) - Q-value: 187.70, ADP: 129.20
#
# Pick 49:
#   1. Trey McBride (TE) - Q-value: 190.87, ADP: 46.60
#   2. Dalton Kincaid (TE) - Q-value: 190.62, ADP: 52.20
#   3. Evan Engram (TE) - Q-value: 189.28, ADP: 65.60
#   4. Kyle Pitts (TE) - Q-value: 188.46, ADP: 61.20
#   5. Jake Ferguson (TE) - Q-value: 186.30, ADP: 87.60
#
# Pick 72:
#   1. Chris Godwin (WR) - Q-value: 179.24, ADP: 76.00
#   2. Calvin Ridley (WR) - Q-value: 179.23, ADP: 75.20
#   3. Terry McLaurin (WR) - Q-value: 178.94, ADP: 74.80
#   4. Rashee Rice (WR) - Q-value: 178.34, ADP: 85.20
#   5. Marquise Brown (WR) - Q-value: 177.45, ADP: 90.00
#
# Pick 73:
#   1. Jared Goff (QB) - Q-value: 172.53, ADP: 118.00
#   2. Jayden Daniels (QB) - Q-value: 172.23, ADP: 109.40
#   3. Caleb Williams (QB) - Q-value: 171.38, ADP: 117.80
#   4. Tua Tagovailoa (QB) - Q-value: 171.37, ADP: 115.60
#   5. Trevor Lawrence (QB) - Q-value: 170.67, ADP: 133.20
#
# Pick 96:
#   1. Brian Robinson Jr. (RB) - Q-value: 155.35, ADP: 97.40
#   2. Javonte Williams (RB) - Q-value: 154.83, ADP: 97.20
#   3. Gus Edwards (RB) - Q-value: 154.54, ADP: 112.20
#   4. Chase Brown (RB) - Q-value: 153.68, ADP: 120.80
#   5. Trey Benson (RB) - Q-value: 153.60, ADP: 121.80
#
# Pick 97:
#   1. Devin Singletary (RB) - Q-value: 125.59, ADP: 98.60
#   2. Chase Brown (RB) - Q-value: 125.22, ADP: 120.80
#   3. Javonte Williams (RB) - Q-value: 125.21, ADP: 97.20
#   4. Ezekiel Elliott (RB) - Q-value: 125.19, ADP: 108.40
#   5. Tyjae Spears (RB) - Q-value: 125.01, ADP: 103.20
#
# Pick 120:
#   1. Blake Corum (RB) - Q-value: 105.08, ADP: 123.20
#   2. Chase Brown (RB) - Q-value: 104.45, ADP: 120.80
#   3. Jerome Ford (RB) - Q-value: 104.26, ADP: 124.60
#   4. J.K. Dobbins (RB) - Q-value: 104.20, ADP: 133.60
#   5. Trey Benson (RB) - Q-value: 104.12, ADP: 121.80
#
# Pick 121:
#   1. Josh Downs (WR) - Q-value: 76.42, ADP: 184.00
#   2. Curtis Samuel (WR) - Q-value: 76.23, ADP: 136.20
#   3. Josh Palmer (WR) - Q-value: 76.18, ADP: 158.80
#   4. Jerry Jeudy (WR) - Q-value: 76.12, ADP: 147.00
#   5. Kendrick Bourne (WR) - Q-value: 76.11, ADP: 279.00
#
# Pick 144:
#   1. Jakobi Meyers (WR) - Q-value: 65.32, ADP: 146.20
#   2. Mike Williams (WR) - Q-value: 65.15, ADP: 143.80
#   3. Jerry Jeudy (WR) - Q-value: 64.63, ADP: 147.00
#   4. Josh Palmer (WR) - Q-value: 64.61, ADP: 158.80
#   5. Brandin Cooks (WR) - Q-value: 64.18, ADP: 160.60
#
# Pick 145:
#   1. MIA (DST) - Q-value: 55.78, ADP: 141.00
#   2. BUF (DST) - Q-value: 50.84, ADP: 174.00
#   3. CHI (DST) - Q-value: 50.47, ADP: 178.00
#   4. TEN (DST) - Q-value: 50.12, ADP: 230.00
#   5. LAC (DST) - Q-value: 50.09, ADP: 179.00
#
# Pick 168:
#   1. Miles Sanders (RB) - Q-value: 25.06, ADP: 252.00
#   2. Chase Edmonds (RB) - Q-value: 24.93, ADP: 462.00
#   3. Kendre Miller (RB) - Q-value: 24.75, ADP: 178.40
#   4. Cody Schrader (RB) - Q-value: 24.73, ADP: 718.00
#   5. Emari Demercado (RB) - Q-value: 24.72, ADP: 443.00
#
# Pick 169:
#   1. Jaleel McLaughlin (RB) - Q-value: 12.71, ADP: 174.40
#   2. Dontayvion Wicks (WR) - Q-value: 12.18, ADP: 186.00
#   3. Rasheen Ali (RB) - Q-value: 12.17, ADP: 376.00
#   4. Deuce Vaughn (RB) - Q-value: 12.07, ADP: 326.00
#   5. Jahan Dotson (WR) - Q-value: 11.96, ADP: 187.00
#
# Pick 192:
#   1. Nyheim Hines (RB) - Q-value: 3.92, ADP: 463.00
#   2. Kenneth Gainwell (RB) - Q-value: 3.82, ADP: 236.30
#   3. Carson Steele (RB) - Q-value: 3.79, ADP: 709.00
#   4. Bucky Irving (RB) - Q-value: 3.77, ADP: 207.00
#   5. Cody Schrader (RB) - Q-value: 3.76, ADP: 718.00
#
# Pick 193:
#   1. Wan'Dale Robinson (WR) - Q-value: 2.26, ADP: 216.50
#   2. Kendrick Bourne (WR) - Q-value: 2.25, ADP: 279.00
#   3. Carson Steele (RB) - Q-value: 2.25, ADP: 709.00
#   4. Demario Douglas (WR) - Q-value: 2.12, ADP: 201.80
#   5. Tim Patrick (WR) - Q-value: 1.77, ADP: 356.00
#
# Pick 216:
#   1. Kendrick Bourne (WR) - Q-value: 1.17, ADP: 279.00
#   2. Carson Steele (RB) - Q-value: 1.16, ADP: 709.00
#   3. Tim Patrick (WR) - Q-value: 0.94, ADP: 356.00
#   4. D'Onta Foreman (RB) - Q-value: 0.90, ADP: 242.50
#   5. DJ Chark (WR) - Q-value: 0.87, ADP: 311.30
#
# Your team:
# CeeDee Lamb (WR) - ADP: 2.00, Projection: 20.90
# Drake London (WR) - ADP: 25.20, Projection: 14.37
# Jalen Hurts (QB) - ADP: 31.80, Projection: 26.95
# George Kittle (TE) - ADP: 59.00, Projection: 11.45
# Trey McBride (TE) - ADP: 46.60, Projection: 11.94
# Chris Godwin (WR) - ADP: 76.00, Projection: 12.32
# Jared Goff (QB) - ADP: 118.00, Projection: 21.01
# Brian Robinson Jr. (RB) - ADP: 97.40, Projection: 11.35
# Devin Singletary (RB) - ADP: 98.60, Projection: 9.81
# Blake Corum (RB) - ADP: 123.20, Projection: 8.69
# Josh Downs (WR) - ADP: 184.00, Projection: 6.34
# Jakobi Meyers (WR) - ADP: 146.20, Projection: 10.72
# MIA (DST) - ADP: 141.00, Projection: 11.66
# Miles Sanders (RB) - ADP: 252.00, Projection: 6.55
# Jaleel McLaughlin (RB) - ADP: 174.40, Projection: 7.35
# Nyheim Hines (RB) - ADP: 463.00, Projection: 2.27
# Wan'Dale Robinson (WR) - ADP: 216.50, Projection: 10.35
# Kendrick Bourne (WR) - ADP: 279.00, Projection: 10.71
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 2, 'K': 0, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 8, 'WR': 4, 'TE': 2, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 9, 'WR': 4, 'TE': 1, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 214.75
# Team 2: 228.58
# Team 3: 223.33
# Team 4: 213.29
# Team 5: 216.72
# Team 6: 214.30
# Team 7: 223.11
# Team 8: 204.64
# Team 9: 220.98
# Team 10: 218.09
# Team 11: 217.05
# Team 12: 213.98

# %%
# Usage and testing
assistant = FantasyFootballDraftAssistant()
assistant.load_data('data//cbs_fantasy_projection_master.csv')

model_file = 'fantasy_football_model.pkl'

# Check if a saved model exists
if os.path.exists(model_file):
    assistant.load_model(model_file)
    print("Continuing training from saved model...")
else:
    print("Starting new training...")

# Train for 10,000 episodes
print("Training the model...")
assistant.train(num_episodes=10000)

# Save the model after training
#assistant.save_model(model_file)

print("\nSimulating a draft for a user in position 3...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=2)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[2]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Starting new training...
# Training the model...
# Training episode 0/10000
# Training episode 1000/10000
# Training episode 2000/10000
# Training episode 3000/10000
# Training episode 4000/10000
# Training episode 5000/10000
# Training episode 6000/10000
# Training episode 7000/10000
# Training episode 8000/10000
# Training episode 9000/10000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 19
#      16 assistant.train(num_episodes=10000)
#      18 # Save the model after training
# ---> 19 assistant.save_model(model_file)
#      21 print("\nSimulating a draft for a user in position 3...")
#      22 user_picks, simulated_teams = assistant.simulate_draft(user_position=2)  # 0-based index
#
# Cell In[35], line 185, in FantasyFootballDraftAssistant.save_model(self, file_path)
#     183 def save_model(self, file_path):
#     184     with open(file_path, 'wb') as f:
# --> 185         pickle.dump((self.q_table, self.total_episodes), f)
#     186     print(f"Model saved to {file_path}")
#
# AttributeError: Can't pickle local object 'FantasyFootballDraftAssistant.__init__.<locals>.<lambda>'

# %%
print("\nSimulating a draft for a user in position 3...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=2)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[2]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 3...
#
# Recommendations for your picks:
#
# Pick 3:
#   1. Tyreek Hill (WR) - Q-value: 239.89, ADP: 3.20
#   2. Amon-Ra St. Brown (WR) - Q-value: 238.73, ADP: 6.80
#   3. Justin Jefferson (WR) - Q-value: 238.25, ADP: 6.00
#   4. Ja'Marr Chase (WR) - Q-value: 236.96, ADP: 5.80
#   5. A.J. Brown (WR) - Q-value: 236.68, ADP: 10.20
#
# Pick 22:
#   1. Alvin Kamara (RB) - Q-value: 214.24, ADP: 39.60
#   2. James Conner (RB) - Q-value: 210.46, ADP: 60.40
#   3. Tank Dell (WR) - Q-value: 210.03, ADP: 63.80
#   4. Dalton Kincaid (TE) - Q-value: 207.45, ADP: 52.20
#   5. Jordan Addison (WR) - Q-value: 204.79, ADP: 96.20
#
# Pick 27:
#   1. Deebo Samuel (WR) - Q-value: 201.82, ADP: 33.00
#   2. Michael Pittman (WR) - Q-value: 201.08, ADP: 32.60
#   3. Josh Jacobs (RB) - Q-value: 191.06, ADP: 30.40
#   4. Javonte Williams (RB) - Q-value: 182.82, ADP: 97.20
#   5. Brandon Aiyuk (WR) - Q-value: 142.17, ADP: 32.80
#
# Pick 46:
#   1. Brock Bowers (TE) - Q-value: 174.04, ADP: 102.40
#   2. Amari Cooper (WR) - Q-value: 173.33, ADP: 55.60
#   3. Trey Benson (RB) - Q-value: 159.41, ADP: 121.80
#   4. Rasheen Ali (RB) - Q-value: 140.98, ADP: 376.00
#   5. Ladd McConkey (WR) - Q-value: 128.03, ADP: 100.00
#
# Pick 51:
#   1. Zack Moss (RB) - Q-value: 153.29, ADP: 89.00
#   2. Kenneth Gainwell (RB) - Q-value: 136.90, ADP: 236.30
#   3. Alexander Mattison (RB) - Q-value: 134.42, ADP: 225.80
#   4. Cole Fotheringham (TE) - Q-value: 131.67, ADP: 650.00
#   5. Theo Johnson (TE) - Q-value: 98.01, ADP: 303.70
#
# Pick 70:
#   1. Jerry Jeudy (WR) - Q-value: 134.19, ADP: 147.00
#   2. Troy Franklin (WR) - Q-value: 125.05, ADP: 198.80
#   3. T.J. Hockenson (TE) - Q-value: 90.58, ADP: 116.20
#   4. Jonnu Smith (TE) - Q-value: 67.30, ADP: 248.00
#   5. Jalen Nailor (WR) - Q-value: 67.30, ADP: 550.00
#
# Pick 75:
#   1. Aaron Rodgers (QB) - Q-value: 133.16, ADP: 145.80
#   2. Hunter Henry (TE) - Q-value: 122.36, ADP: 194.00
#   3. Kendrick Bourne (WR) - Q-value: 106.26, ADP: 279.00
#   4. Dontayvion Wicks (WR) - Q-value: 105.17, ADP: 186.00
#   5. Jayden Daniels (QB) - Q-value: 104.02, ADP: 109.40
#
# Pick 94:
#   1. Robert Tonyan (TE) - Q-value: 102.88, ADP: 735.00
#   2. Quentin Johnston (WR) - Q-value: 93.39, ADP: 198.30
#   3. Deshaun Watson (QB) - Q-value: 68.84, ADP: 168.40
#   4. Jakobi Meyers (WR) - Q-value: 46.08, ADP: 146.20
#   5. Carter Bradley (QB) - Q-value: 42.54, ADP: 886.00
#
# Pick 99:
#   1. Bryce Young (QB) - Q-value: 113.22, ADP: 218.30
#   2. Jordan Addison (WR) - Q-value: 108.82, ADP: 96.20
#   3. Tyler Lockett (WR) - Q-value: 105.93, ADP: 131.20
#   4. Zay Jones (WR) - Q-value: 98.77, ADP: 290.00
#   5. Darnell Mooney (WR) - Q-value: 97.42, ADP: 195.60
#
# Pick 118:
#   1. Trey Benson (RB) - Q-value: 109.02, ADP: 121.80
#   2. Chuba Hubbard (RB) - Q-value: 107.29, ADP: 150.80
#   3. Rico Dowdle (RB) - Q-value: 106.76, ADP: 159.60
#   4. Antonio Gibson (RB) - Q-value: 106.16, ADP: 170.40
#   5. AJ Dillon (RB) - Q-value: 100.59, ADP: 235.30
#
# Pick 123:
#   1. Brian Thomas Jr. (WR) - Q-value: 96.63, ADP: 124.00
#   2. Curtis Samuel (WR) - Q-value: 95.45, ADP: 136.20
#   3. Mike Williams (WR) - Q-value: 94.65, ADP: 143.80
#   4. Tyler Lockett (WR) - Q-value: 94.51, ADP: 131.20
#   5. Romeo Doubs (WR) - Q-value: 92.48, ADP: 142.60
#
# Pick 142:
#   1. Mike Williams (WR) - Q-value: 86.37, ADP: 143.80
#   2. Romeo Doubs (WR) - Q-value: 86.18, ADP: 142.60
#   3. Jakobi Meyers (WR) - Q-value: 86.17, ADP: 146.20
#   4. Brandin Cooks (WR) - Q-value: 84.93, ADP: 160.60
#   5. Josh Palmer (WR) - Q-value: 84.83, ADP: 158.80
#
# Pick 147:
#   1. KC (DST) - Q-value: 81.19, ADP: 140.00
#   2. MIA (DST) - Q-value: 79.45, ADP: 141.00
#   3. NO (DST) - Q-value: 77.63, ADP: 137.00
#   4. LAC (DST) - Q-value: 74.09, ADP: 179.00
#   5. BUF (DST) - Q-value: 73.99, ADP: 174.00
#
# Pick 166:
#   1. Antonio Gibson (RB) - Q-value: 56.45, ADP: 170.40
#   2. Carson Steele (RB) - Q-value: 55.80, ADP: 709.00
#   3. Jaylen Wright (RB) - Q-value: 55.60, ADP: 170.80
#   4. Kendre Miller (RB) - Q-value: 55.50, ADP: 178.40
#   5. D'Onta Foreman (RB) - Q-value: 54.31, ADP: 242.50
#
# Pick 171:
#   1. Rashid Shaheed (WR) - Q-value: 42.86, ADP: 174.80
#   2. Roman Wilson (WR) - Q-value: 41.75, ADP: 192.50
#   3. Dontayvion Wicks (WR) - Q-value: 41.70, ADP: 186.00
#   4. Alec Pierce (WR) - Q-value: 40.60, ADP: 374.50
#   5. Wan'Dale Robinson (WR) - Q-value: 40.34, ADP: 216.50
#
# Pick 190:
#   1. Will Shipley (RB) - Q-value: 24.82, ADP: 246.30
#   2. Carson Steele (RB) - Q-value: 24.64, ADP: 709.00
#   3. Chase Edmonds (RB) - Q-value: 24.22, ADP: 462.00
#   4. Emari Demercado (RB) - Q-value: 23.66, ADP: 443.00
#   5. Nyheim Hines (RB) - Q-value: 23.63, ADP: 463.00
#
# Pick 195:
#   1. Alec Pierce (WR) - Q-value: 3.51, ADP: 374.50
#   2. Jermaine Burton (WR) - Q-value: 2.93, ADP: 208.50
#   3. Carson Steele (RB) - Q-value: 2.86, ADP: 709.00
#   4. Isaac Guerendo (RB) - Q-value: 2.80, ADP: 318.70
#   5. DJ Chark (WR) - Q-value: 2.66, ADP: 311.30
#
# Pick 214:
#   1. Carson Steele (RB) - Q-value: 1.27, ADP: 709.00
#   2. Kendrick Bourne (WR) - Q-value: 1.12, ADP: 279.00
#   3. D'Onta Foreman (RB) - Q-value: 0.94, ADP: 242.50
#   4. Tim Patrick (WR) - Q-value: 0.91, ADP: 356.00
#   5. Darius Slayton (WR) - Q-value: 0.90, ADP: 299.50
#
# Your team:
# Tyreek Hill (WR) - ADP: 3.20, Projection: 19.44
# Alvin Kamara (RB) - ADP: 39.60, Projection: 14.76
# Deebo Samuel (WR) - ADP: 33.00, Projection: 14.65
# Brock Bowers (TE) - ADP: 102.40, Projection: 9.78
# Zack Moss (RB) - ADP: 89.00, Projection: 11.42
# Jerry Jeudy (WR) - ADP: 147.00, Projection: 10.35
# Aaron Rodgers (QB) - ADP: 145.80, Projection: 17.46
# Robert Tonyan (TE) - ADP: 735.00, Projection: 1.76
# Bryce Young (QB) - ADP: 218.30, Projection: 14.87
# Trey Benson (RB) - ADP: 121.80, Projection: 8.69
# Brian Thomas Jr. (WR) - ADP: 124.00, Projection: 10.90
# Mike Williams (WR) - ADP: 143.80, Projection: 10.94
# KC (DST) - ADP: 140.00, Projection: 13.21
# Antonio Gibson (RB) - ADP: 170.40, Projection: 9.25
# Rashid Shaheed (WR) - ADP: 174.80, Projection: 10.11
# Will Shipley (RB) - ADP: 246.30, Projection: 1.83
# Alec Pierce (WR) - ADP: 374.50, Projection: 5.64
# Carson Steele (RB) - ADP: 709.00, Projection: 10.99
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 2, 'K': 0, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 8, 'WR': 4, 'TE': 2, 'K': 1, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 7, 'WR': 6, 'TE': 1, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 222.86
# Team 2: 215.68
# Team 3: 196.05
# Team 4: 220.50
# Team 5: 207.40
# Team 6: 219.85
# Team 7: 223.32
# Team 8: 214.09
# Team 9: 224.14
# Team 10: 219.35
# Team 11: 223.00
# Team 12: 226.24

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

class FantasyFootballDraftAssistant:
    def __init__(self):
        self.df = None
        self.positions = {'QB': (1, 3), 'RB': (3, 9), 'WR': (4, 9), 'TE': (1, 3), 'K': (1, 1), 'DST': (1, 2)}
        self.starting_positions = {'QB': 1, 'RB': 2, 'WR': 3, 'TE': 1, 'K': 1, 'DST': 1, 'FLEX': 1}
        self.flex_positions = ['RB', 'WR', 'TE']
        self.q_table = defaultdict(lambda: defaultdict(float))
        self.alpha = 0.1  # Learning rate
        self.gamma = 0.9  # Discount factor
        self.epsilon = 0.1  # Exploration rate
        
    def load_data(self, file_path):
        self.df = pd.read_csv(file_path)
        self.df['ADP'] = pd.to_numeric(self.df['ADP'], errors='coerce')
        self.df = self.df.sort_values('ppr_projection', ascending=False).reset_index(drop=True)
        self.players = self.df.to_dict('records')
        
    def get_state(self, team, round_num):
        return (tuple(sum(1 for p in team if p['pos'] == pos) for pos in self.positions.keys()), round_num)
    
    def get_actions(self, available_players, team, round_num):
        actions = []
        for player in available_players:
            pos = player['pos']
            pos_count = sum(1 for p in team if p['pos'] == pos)
            if pos_count < self.positions[pos][1] and (pos not in ['K', 'DST'] or round_num > 12):
                actions.append(player['player'])
        return actions
    
    def calculate_team_value(self, team):
        weekly_scores = []
        for week in range(1, 18):  # 17-week season
            available_players = [p for p in team if p['bye_week'] != week]
            starters = self.select_starters(available_players)
            week_score = sum(p['ppr_projection'] / 17 for p in starters)
            weekly_scores.append(week_score)
        
        total_score = sum(weekly_scores)
        bench_strength = sum(p['ppr_projection'] for p in team) - sum(p['ppr_projection'] for p in self.select_starters(team))
        return total_score + (bench_strength * 0.1)  # Adding some value for bench strength
    
    def select_starters(self, available_players):
        starters = []
        for pos, count in self.starting_positions.items():
            if pos == 'FLEX':
                flex_options = sorted([p for p in available_players if p['pos'] in self.flex_positions and p not in starters], 
                                      key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(flex_options[:count])
            else:
                pos_players = sorted([p for p in available_players if p['pos'] == pos and p not in starters], 
                                     key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(pos_players[:count])
        return starters
    
    def calculate_reward(self, team, player, round_num):
        team_value_before = self.calculate_team_value(team)
        new_team = team + [player]
        team_value_after = self.calculate_team_value(new_team)
        value_added = team_value_after - team_value_before
        
        adp_bonus = max(0, (200 - player['ADP']) / 10) if not np.isnan(player['ADP']) else 0
        round_penalty = max(0, round_num - 10) * 2 if player['pos'] in ['K', 'DST'] else 0
        
        return value_added + adp_bonus - round_penalty
    
    def train(self, num_episodes=10000, num_teams=12):
        for episode in range(num_episodes):
            if episode % 1000 == 0:
                print(f"Training episode {episode}/{num_episodes}")
            
            teams = [[] for _ in range(num_teams)]
            available_players = self.players.copy()
            
            for round_num in range(1, 19):
                for team_index in range(num_teams):
                    state = self.get_state(teams[team_index], round_num)
                    actions = self.get_actions(available_players, teams[team_index], round_num)
                    
                    if not actions:
                        continue
                    
                    if np.random.uniform(0, 1) < self.epsilon:
                        action = np.random.choice(actions)
                    else:
                        q_values = [self.q_table[state][a] for a in actions]
                        action = actions[np.argmax(q_values)]
                    
                    player = next(p for p in available_players if p['player'] == action)
                    reward = self.calculate_reward(teams[team_index], player, round_num)
                    teams[team_index].append(player)
                    available_players = [p for p in available_players if p['player'] != action]
                    
                    next_state = self.get_state(teams[team_index], round_num + 1)
                    
                    # Q-value update
                    max_future_q = max([self.q_table[next_state][a] for a in self.get_actions(available_players, teams[team_index], round_num + 1)], default=0)
                    current_q = self.q_table[state][action]
                    new_q = (1 - self.alpha) * current_q + self.alpha * (reward + self.gamma * max_future_q)
                    self.q_table[state][action] = new_q
    
    def recommend_players(self, team, available_players, round_num, num_recommendations=5):
        state = self.get_state(team, round_num)
        actions = self.get_actions(available_players, team, round_num)
        q_values = [(a, self.q_table[state][a]) for a in actions]
        top_actions = sorted(q_values, key=lambda x: x[1], reverse=True)[:num_recommendations]
        return [(next(p for p in available_players if p['player'] == a), q) for a, q in top_actions]
    
    def simulate_draft(self, user_position, num_teams=12):
        teams = [[] for _ in range(num_teams)]
        available_players = self.players.copy()
        user_picks = []
        
        for round_num in range(1, 19):
            draft_order = range(num_teams) if round_num % 2 == 1 else reversed(range(num_teams))
            for pick_in_round, team_index in enumerate(draft_order):
                if team_index == user_position:
                    recommendations = self.recommend_players(teams[team_index], available_players, round_num)
                    user_picks.append(((round_num - 1) * num_teams + pick_in_round + 1, recommendations))
                    
                    if recommendations:
                        selected_player, _ = recommendations[0]
                        teams[team_index].append(selected_player)
                        available_players = [p for p in available_players if p['player'] != selected_player['player']]
                else:
                    actions = self.get_actions(available_players, teams[team_index], round_num)
                    if actions:
                        player = max(
                            [p for p in available_players if p['player'] in actions],
                            key=lambda p: p['ppr_projection'] - (round_num * 2 if p['pos'] in ['K', 'DST'] else 0)
                        )
                        teams[team_index].append(player)
                        available_players = [p for p in available_players if p['player'] != player['player']]
        
        return user_picks, teams

# Usage and testing
assistant = FantasyFootballDraftAssistant()
assistant.load_data('data//cbs_fantasy_projection_master.csv')

print("Training the model...")
assistant.train(num_episodes=10000)  # Increase this for better results

print("\nSimulating a draft for a user in position 3...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=2)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}")

print("\nYour team:")
for player in simulated_teams[2]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Training the model...
# Training episode 0/10000
# Training episode 1000/10000
# Training episode 2000/10000
# Training episode 3000/10000
# Training episode 4000/10000
# Training episode 5000/10000
# Training episode 6000/10000
# Training episode 7000/10000
# Training episode 8000/10000
# Training episode 9000/10000
#
# Simulating a draft for a user in position 3...
#
# Recommendations for your picks:
#
# Pick 3:
#   1. Patrick Mahomes (QB) - Q-value: 225.39
#   2. Lamar Jackson (QB) - Q-value: 224.04
#   3. C.J. Stroud (QB) - Q-value: 221.75
#   4. Joe Burrow (QB) - Q-value: 220.93
#   5. Anthony Richardson (QB) - Q-value: 220.77
#
# Pick 22:
#   1. Tyreek Hill (WR) - Q-value: 205.07
#   2. Amon-Ra St. Brown (WR) - Q-value: 204.05
#   3. A.J. Brown (WR) - Q-value: 202.28
#   4. Puka Nacua (WR) - Q-value: 202.13
#   5. Davante Adams (WR) - Q-value: 199.64
#
# Pick 27:
#   1. Bijan Robinson (RB) - Q-value: 185.65
#   2. Travis Etienne (RB) - Q-value: 178.73
#   3. Derrick Henry (RB) - Q-value: 178.47
#   4. Joe Mixon (RB) - Q-value: 176.22
#   5. Bo Nix (QB) - Q-value: 172.51
#
# Pick 46:
#   1. Travis Etienne (RB) - Q-value: 164.40
#   2. Josh Jacobs (RB) - Q-value: 158.82
#   3. J.J. McCarthy (QB) - Q-value: 157.98
#   4. Bryce Young (QB) - Q-value: 157.27
#   5. Taysom Hill (QB) - Q-value: 157.02
#
# Pick 51:
#   1. Bryce Young (QB) - Q-value: 142.12
#   2. Drew Lock (QB) - Q-value: 139.78
#   3. Michael Penix Jr. (QB) - Q-value: 139.78
#   4. Kyle Trask (QB) - Q-value: 139.37
#   5. Taysom Hill (QB) - Q-value: 137.63
#
# Pick 70:
#   1. Mark Andrews (TE) - Q-value: 155.18
#   2. Stefon Diggs (WR) - Q-value: 147.26
#   3. Malik Nabers (WR) - Q-value: 144.03
#   4. Christian Kirk (WR) - Q-value: 142.60
#   5. Romeo Doubs (WR) - Q-value: 134.10
#
# Pick 75:
#   1. Jaylen Waddle (WR) - Q-value: 139.96
#   2. T.J. Hockenson (TE) - Q-value: 124.17
#   3. Wan'Dale Robinson (WR) - Q-value: 121.56
#   4. KaVontae Turpin (WR) - Q-value: 118.44
#   5. Jaxon Smith-Njigba (WR) - Q-value: 118.30
#
# Pick 94:
#   1. George Kittle (TE) - Q-value: 121.61
#   2. Xavier Worthy (WR) - Q-value: 117.63
#   3. Rome Odunze (WR) - Q-value: 116.54
#   4. Khalil Shakir (WR) - Q-value: 113.42
#   5. Christian Watson (WR) - Q-value: 112.10
#
# Pick 99:
#   1. Tony Pollard (RB) - Q-value: 105.44
#   2. Jaylen Warren (RB) - Q-value: 105.15
#   3. Brian Thomas Jr. (WR) - Q-value: 103.93
#   4. Tyler Lockett (WR) - Q-value: 102.81
#   5. Odell Beckham Jr. (WR) - Q-value: 95.84
#
# Pick 118:
#   1. Tyler Lockett (WR) - Q-value: 94.32
#   2. Jahan Dotson (WR) - Q-value: 87.66
#   3. Kendrick Bourne (WR) - Q-value: 87.55
#   4. Adam Thielen (WR) - Q-value: 76.45
#   5. Darnell Mooney (WR) - Q-value: 65.12
#
# Pick 123:
#   1. Jordan Addison (WR) - Q-value: 87.61
#   2. Rome Odunze (WR) - Q-value: 87.22
#   3. Josh Palmer (WR) - Q-value: 81.16
#   4. Adonai Mitchell (WR) - Q-value: 80.16
#   5. Troy Franklin (WR) - Q-value: 78.95
#
# Pick 142:
#   1. Sam Darnold (QB) - Q-value: 68.43
#   2. Jameis Winston (QB) - Q-value: 67.84
#   3. Sam Howell (QB) - Q-value: 67.32
#   4. Michael Pratt (QB) - Q-value: 67.13
#   5. Drake Maye (QB) - Q-value: 66.86
#
# Pick 147:
#   1. NYJ (DST) - Q-value: 68.53
#   2. NO (DST) - Q-value: 60.62
#   3. Xavier Legette (WR) - Q-value: 59.59
#   4. Tim Patrick (WR) - Q-value: 57.20
#   5. A.T. Perry (WR) - Q-value: 57.06
#
# Pick 166:
#   1. Jonnu Smith (TE) - Q-value: 56.47
#   2. Lucas Krull (TE) - Q-value: 55.79
#   3. Brayden Willis (TE) - Q-value: 52.43
#   4. Peyton Hendershot (TE) - Q-value: 48.45
#   5. Brandon Johnson (WR) - Q-value: 43.99
#
# Pick 171:
#   1. Roman Wilson (WR) - Q-value: 52.59
#   2. Demarcus Robinson (WR) - Q-value: 51.38
#   3. Quentin Johnston (WR) - Q-value: 51.04
#   4. Zay Jones (WR) - Q-value: 50.29
#   5. Alexander Mattison (RB) - Q-value: 38.50
#
# Pick 190:
#   1. Zach Charbonnet (RB) - Q-value: 43.63
#   2. Jaleel McLaughlin (RB) - Q-value: 41.04
#   3. MarShawn Lloyd (RB) - Q-value: 40.97
#   4. Jaylen Wright (RB) - Q-value: 40.82
#   5. Kendre Miller (RB) - Q-value: 40.66
#
# Pick 195:
#   1. Ja'Lynn Polk (WR) - Q-value: 18.45
#   2. Jonathan Mingo (WR) - Q-value: 18.41
#   3. Josh Downs (WR) - Q-value: 18.40
#   4. Darnell Mooney (WR) - Q-value: 18.02
#   5. Ricky Pearsall (WR) - Q-value: 17.75
#
# Pick 214:
#   1. Josh Downs (WR) - Q-value: 2.27
#   2. Elijah Mitchell (RB) - Q-value: 1.52
#   3. Ricky Pearsall (WR) - Q-value: 1.46
#   4. Justin Tucker (K) - Q-value: 1.10
#   5. Roschon Johnson (RB) - Q-value: 0.66
#
# Your team:
# Patrick Mahomes (QB) - ADP: 29.60, Projection: 23.85
# Tyreek Hill (WR) - ADP: 3.20, Projection: 19.44
# Bijan Robinson (RB) - ADP: 6.00, Projection: 19.44
# Travis Etienne (RB) - ADP: 18.20, Projection: 15.07
# Bryce Young (QB) - ADP: 218.30, Projection: 14.87
# Mark Andrews (TE) - ADP: 43.60, Projection: 12.76
# Jaylen Waddle (WR) - ADP: 40.80, Projection: 13.11
# George Kittle (TE) - ADP: 59.00, Projection: 11.45
# Tony Pollard (RB) - ADP: 82.00, Projection: 10.95
# Tyler Lockett (WR) - ADP: 131.20, Projection: 10.59
# Jordan Addison (WR) - ADP: 96.20, Projection: 10.71
# Sam Darnold (QB) - ADP: 283.00, Projection: 4.42
# NYJ (DST) - ADP: 101.00, Projection: 14.00
# Jonnu Smith (TE) - ADP: 248.00, Projection: 7.26
# Roman Wilson (WR) - ADP: 192.50, Projection: 7.78
# Zach Charbonnet (RB) - ADP: 132.20, Projection: 7.03
# Ja'Lynn Polk (WR) - ADP: 201.00, Projection: 6.52
# Josh Downs (WR) - ADP: 184.00, Projection: 6.34
#
# Position distribution for all teams:
# Team 1: {'QB': 3, 'RB': 7, 'WR': 5, 'TE': 3, 'K': 0, 'DST': 0}
# Team 2: {'QB': 3, 'RB': 6, 'WR': 7, 'TE': 2, 'K': 0, 'DST': 0}
# Team 3: {'QB': 3, 'RB': 4, 'WR': 7, 'TE': 3, 'K': 0, 'DST': 1}
# Team 4: {'QB': 3, 'RB': 5, 'WR': 7, 'TE': 3, 'K': 0, 'DST': 0}
# Team 5: {'QB': 3, 'RB': 6, 'WR': 6, 'TE': 3, 'K': 0, 'DST': 0}
# Team 6: {'QB': 3, 'RB': 6, 'WR': 6, 'TE': 3, 'K': 0, 'DST': 0}
# Team 7: {'QB': 3, 'RB': 4, 'WR': 9, 'TE': 2, 'K': 0, 'DST': 0}
# Team 8: {'QB': 3, 'RB': 5, 'WR': 7, 'TE': 3, 'K': 0, 'DST': 0}
# Team 9: {'QB': 3, 'RB': 5, 'WR': 8, 'TE': 2, 'K': 0, 'DST': 0}
# Team 10: {'QB': 2, 'RB': 6, 'WR': 9, 'TE': 1, 'K': 0, 'DST': 0}
# Team 11: {'QB': 2, 'RB': 4, 'WR': 9, 'TE': 3, 'K': 0, 'DST': 0}
# Team 12: {'QB': 2, 'RB': 6, 'WR': 9, 'TE': 1, 'K': 0, 'DST': 0}
#
# Total projected points for each team:
# Team 1: 225.43
# Team 2: 224.48
# Team 3: 215.59
# Team 4: 222.32
# Team 5: 221.77
# Team 6: 221.83
# Team 7: 221.09
# Team 8: 220.98
# Team 9: 221.20
# Team 10: 220.23
# Team 11: 220.09
# Team 12: 220.89

# %%
# Usage and testing
assistant = FantasyFootballDraftAssistant()
assistant.load_data('cbs_fantasy_projection_master.csv')

# %%
print("Training the model...")
assistant.train(num_episodes=1000)  # Increase this for better results

print("\nSimulating a draft for a user in position 3...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=2)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}")

# Analyze final team compositions and print user's team
print("\nYour team:")
for player in simulated_teams[2]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']})")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")
# Out:
# Training the model...
# Training episode 0/1000
# Training episode 10/1000
# Training episode 20/1000
# Training episode 30/1000
# Training episode 40/1000
# Training episode 50/1000
# Training episode 60/1000
# Training episode 70/1000
# Training episode 80/1000
# Training episode 90/1000
# Training episode 100/1000
# Training episode 110/1000
# Training episode 120/1000
# Training episode 130/1000
# Training episode 140/1000
# Training episode 150/1000
# Training episode 160/1000
# Training episode 170/1000
# Training episode 180/1000
# Training episode 190/1000
# Training episode 200/1000
# Training episode 210/1000
# Training episode 220/1000
# Training episode 230/1000
# Training episode 240/1000
# Training episode 250/1000
# Training episode 260/1000
# Training episode 270/1000
# Training episode 280/1000
# Training episode 290/1000
# Training episode 300/1000
# Training episode 310/1000
# Training episode 320/1000
# Training episode 330/1000
# Training episode 340/1000
# Training episode 350/1000
# Training episode 360/1000
# Training episode 370/1000
# Training episode 380/1000
# Training episode 390/1000
# Training episode 400/1000
# Training episode 410/1000
# Training episode 420/1000
# Training episode 430/1000
# Training episode 440/1000
# Training episode 450/1000
# Training episode 460/1000
# Training episode 470/1000
# Training episode 480/1000
# Training episode 490/1000
# Training episode 500/1000
# Training episode 510/1000
# Training episode 520/1000
# Training episode 530/1000
# Training episode 540/1000
# Training episode 550/1000
# Training episode 560/1000
# Training episode 570/1000
# Training episode 580/1000
# Training episode 590/1000
# Training episode 600/1000
# Training episode 610/1000
# Training episode 620/1000
# Training episode 630/1000
# Training episode 640/1000
# Training episode 650/1000
# Training episode 660/1000
# Training episode 670/1000
# Training episode 680/1000
# Training episode 690/1000
# Training episode 700/1000
# Training episode 710/1000
# Training episode 720/1000
# Training episode 730/1000
# Training episode 740/1000
# Training episode 750/1000
# Training episode 760/1000
# Training episode 770/1000
# Training episode 780/1000
# Training episode 790/1000
# Training episode 800/1000
# Training episode 810/1000
# Training episode 820/1000
# Training episode 830/1000
# Training episode 840/1000
# Training episode 850/1000
# Training episode 860/1000
# Training episode 870/1000
# Training episode 880/1000
# Training episode 890/1000
# Training episode 900/1000
# Training episode 910/1000
# Training episode 920/1000
# Training episode 930/1000
# Training episode 940/1000
# Training episode 950/1000
# Training episode 960/1000
# Training episode 970/1000
# Training episode 980/1000
# Training episode 990/1000
#
# Simulating a draft for a user in position 3...
#
# Recommendations for your picks:
#
# Pick 3:
#   1. J.K. Dobbins (RB) - Q-value: 1812.30
#   2. Adam Trautman (TE) - Q-value: 571.51
#   3. James Cook (RB) - Q-value: 528.06
#   4. Cooper Rush (QB) - Q-value: 499.82
#   5. Jonnu Smith (TE) - Q-value: 443.98
#
# Pick 22:
#   1. Keenan Allen (WR) - Q-value: 1809.57
#   2. Zay Jones (WR) - Q-value: 1295.70
#   3. Roschon Johnson (RB) - Q-value: 715.21
#   4. D'Onta Foreman (RB) - Q-value: 488.94
#   5. Justin Fields (QB) - Q-value: 486.50
#
# Pick 27:
#   1. DEN (DST) - Q-value: 1811.86
#   2. Luke Musgrave (TE) - Q-value: 1723.23
#   3. Wil Lutz (K) - Q-value: 682.49
#   4. Cameron Dicker (K) - Q-value: 593.23
#   5. Connor Heyward (TE) - Q-value: 528.81
#
# Pick 46:
#   1. Jalen Nailor (WR) - Q-value: 1812.00
#   2. Tanner McLachlan (TE) - Q-value: 1491.80
#   3. Quintin Morris (TE) - Q-value: 517.88
#   4. BUF (DST) - Q-value: 501.77
#   5. Trey Benson (RB) - Q-value: 493.83
#
# Pick 51:
#   1. Jared Wiley (TE) - Q-value: 1769.60
#   2. Jake Elliott (K) - Q-value: 1592.72
#   3. Sam Darnold (QB) - Q-value: 518.89
#   4. Tyler Goodson (RB) - Q-value: 467.47
#   5. Jamaal Williams (RB) - Q-value: 397.39
#
# Pick 70:
#   1. Dameon Pierce (RB) - Q-value: 1769.82
#   2. Jonathon Brooks (RB) - Q-value: 1750.59
#   3. HOU (DST) - Q-value: 582.02
#   4. Devin Singletary (RB) - Q-value: 544.29
#   5. DAL (DST) - Q-value: 523.94
#
# Pick 75:
#   1. Diontae Johnson (WR) - Q-value: 1800.53
#   2. Joshua Karty (K) - Q-value: 1698.65
#   3. CAR (DST) - Q-value: 449.32
#   4. Cade Otton (TE) - Q-value: 400.96
#   5. Josh Johnson (QB) - Q-value: 385.67
#
# Pick 94:
#   1. MIN (DST) - Q-value: 1157.26
#   2. Juwan Johnson (TE) - Q-value: 480.09
#   3. IND (DST) - Q-value: 364.22
#   4. Jaxon Smith-Njigba (WR) - Q-value: 338.12
#   5. Hunter Long (TE) - Q-value: 336.90
#
# Pick 99:
#   1. Kyle Trask (QB) - Q-value: 1625.71
#   2. Teagan Quitoriano (TE) - Q-value: 144.39
#   3. Stone Smartt (TE) - Q-value: 9.84
#   4. Eric Saubert (TE) - Q-value: 9.82
#   5. Jaylen Wright (RB) - Q-value: 9.79
#
# Pick 118:
#   1. Trenton Irwin (WR) - Q-value: 1627.74
#   2. Austin Hooper (TE) - Q-value: 518.15
#   3. Gus Edwards (RB) - Q-value: 199.76
#   4. Armani Rogers (TE) - Q-value: 173.29
#   5. Adam Thielen (WR) - Q-value: 9.90
#
# Pick 123:
#   1. Brandin Cooks (WR) - Q-value: 1498.93
#   2. Bo Nix (QB) - Q-value: 578.43
#   3. Pharaoh Brown (TE) - Q-value: 190.83
#   4. Ray Davis (RB) - Q-value: 9.93
#   5. D'Onta Foreman (RB) - Q-value: 9.86
#
# Pick 142:
#   1. Joe Flacco (QB) - Q-value: 1452.59
#   2. Hunter Henry (TE) - Q-value: 579.67
#   3. Parris Campbell (WR) - Q-value: 321.43
#   4. Jason Sanders (K) - Q-value: 9.83
#   5. Zach Charbonnet (RB) - Q-value: 9.83
#
# Pick 147:
#   1. Tucker Kraft (TE) - Q-value: 1286.54
#   2. Josh Johnson (QB) - Q-value: 146.60
#   3. Justin Fields (QB) - Q-value: 9.91
#   4. Kendre Miller (RB) - Q-value: 9.74
#   5. Ray Davis (RB) - Q-value: 9.73
#
# Pick 166:
#   1. Audric Estime (RB) - Q-value: 322.95
#   2. Hunter Henry (TE) - Q-value: 184.44
#   3. Gerald Everett (TE) - Q-value: 183.89
#   4. Josh Downs (WR) - Q-value: 9.89
#   5. Braelon Allen (RB) - Q-value: 9.77
#
# Pick 171:
#   1. Dawson Knox (TE) - Q-value: 468.09
#   2. KaVontae Turpin (WR) - Q-value: 9.96
#   3. Hunter Long (TE) - Q-value: 9.92
#   4. Isaiah Likely (TE) - Q-value: 9.88
#   5. Trey Palmer (WR) - Q-value: 9.82
#
# Pick 190:
#   1. Michael Pratt (QB) - Q-value: 198.64
#   2. Gardner Minshew (QB) - Q-value: 177.22
#   3. Bryce Young (QB) - Q-value: 9.87
#   4. Jonathan Mingo (WR) - Q-value: 9.86
#   5. Greg Dortch (WR) - Q-value: 9.71
#
# Pick 195:
#   1. Samaje Perine (RB) - Q-value: 616.44
#   2. Michael Wilson (WR) - Q-value: 182.46
#   3. Jonathan Mingo (WR) - Q-value: 9.83
#   4. JaMycal Hasty (RB) - Q-value: 9.76
#   5. Alexander Mattison (RB) - Q-value: 9.71
#
# Pick 214:
#   1. Jason Myers (K) - Q-value: 1111.19
#   2. Braelon Allen (RB) - Q-value: 476.87
#   3. Tyler Bass (K) - Q-value: 9.69
#   4. Ameer Abdullah (RB) - Q-value: 9.67
#   5. JaMycal Hasty (RB) - Q-value: 9.31
#
# Your team:
# J.K. Dobbins (RB)
# Keenan Allen (WR)
# DEN (DST)
# Jalen Nailor (WR)
# Jared Wiley (TE)
# Dameon Pierce (RB)
# Diontae Johnson (WR)
# MIN (DST)
# Kyle Trask (QB)
# Trenton Irwin (WR)
# Brandin Cooks (WR)
# Joe Flacco (QB)
# Tucker Kraft (TE)
# Audric Estime (RB)
# Dawson Knox (TE)
# Michael Pratt (QB)
# Samaje Perine (RB)
# Jason Myers (K)
#
# Position distribution for all teams:
# Team 1: {'QB': 3, 'RB': 5, 'WR': 6, 'TE': 1, 'K': 1, 'DST': 2}
# Team 2: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 1, 'K': 1, 'DST': 2}
# Team 3: {'QB': 3, 'RB': 4, 'WR': 5, 'TE': 3, 'K': 1, 'DST': 2}
# Team 4: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 2}
# Team 5: {'QB': 2, 'RB': 6, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 2}
# Team 6: {'QB': 3, 'RB': 4, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 2}
# Team 7: {'QB': 2, 'RB': 6, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 2}
# Team 8: {'QB': 3, 'RB': 4, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 2}
# Team 9: {'QB': 3, 'RB': 3, 'WR': 6, 'TE': 3, 'K': 1, 'DST': 2}
# Team 10: {'QB': 2, 'RB': 5, 'WR': 6, 'TE': 3, 'K': 1, 'DST': 1}
# Team 11: {'QB': 1, 'RB': 6, 'WR': 5, 'TE': 3, 'K': 1, 'DST': 2}
# Team 12: {'QB': 2, 'RB': 5, 'WR': 8, 'TE': 1, 'K': 1, 'DST': 1}
