# %%
import pandas as pd
##Load all the cs files from the folder and merge them into one file
import glob
import os
import numpy as np
os.chdir('D:/Work/Github/nflfantasydraft')

# %%
def load_csv_files(directory):
    all_files = glob.glob(os.path.join(directory, "*.csv"))
    if not all_files:
        raise Exception(f"No CSV files found in directory {directory}")
    
    df_from_each_file = (pd.read_csv(f, keep_default_na=False) for f in all_files)
    
    try:
        concatenated_df = pd.concat(df_from_each_file, ignore_index=True)
    except ValueError as e:
        raise Exception("Unable to concatenate CSV files. Check if the files are not empty.") from e
    
    concatenated_df.reset_index(drop=True, inplace=True)
    
    # Convert numerical columns to appropriate types
    numerical_columns = ['non_ppr_projection', 'ppr_projection', 'bye_week', 'ADP']
    for col in numerical_columns:
        concatenated_df[col] = pd.to_numeric(concatenated_df[col], errors='coerce')
    
    # Handle 'rookie' column
    concatenated_df['rookie'] = concatenated_df['rookie'].fillna('No')
    concatenated_df['rookie'] = np.where(concatenated_df['rookie'] == '', 'No', 'Yes')
    
    return concatenated_df

# %%
d

# %%
df=load_csv_files('bot//documents//player_outlook')

# %%
df.head()
# Out:
#             player pos team  non_ppr_projection  ppr_projection  bye_week  \
# 0      Aaron Jones  RB  MIN                 140       12.576471         6
# 1    Aaron Rodgers  QB  NYJ                 273       17.456471        12
# 2     Adam Thielen  WR  CAR                  91        9.888235        11
# 3  Adonai Mitchell  WR  IND                  86        8.847059        14
# 4       A.J. Brown  WR  PHI                 185       17.223529         5
#
#      ADP rookie                                            Outlook
# 0   59.8     No  **Aaron Jones Player Report**\n\n**Overview**\...
# 1  145.8     No  **Aaron Rodgers Player Report**\n\n**Overview*...
# 2  170.8     No  Unfortunately, it seems that the agent couldn'...
# 3  172.2    Yes  **Player Report: Adonai Mitchell**\n\n**Overvi...
# 4   10.2     No  Here is the detailed player report for A.J. Br...

# %%
import http.client

conn = http.client.HTTPSConnection("nfl-football-api.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "b068257286msh1b058683a58c7b7p13a8aejsna8338b4b0df2",
    'x-rapidapi-host': "nfl-football-api.p.rapidapi.com"
}

conn.request("GET", "/nfl-ath-news?id=14876", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"news":[{"headline":"Ranking best remaining 2024 NFL free agents: Who's unsigned?","lastModified":"2024-04-30T15:39:11.000+00:00","root":"nfl","premium":true,"type":"Story","section":"NFL","id":39716609,"linkText":"Ranking the best remaining NFL free agents: Who will land Xavien Howard?","categorized":"2024-04-30T11:00:00Z","metrics":[{"count":0,"type":"views"},{"count":0,"type":"fShares"},{"count":0,"type":"tweets"},{"count":0,"type":"comments"},{"count":0,"type":"emails"},{"count":0,"type":"votes"},{"count":0,"type":"popularity"}],"description":"Who is still available? Let's restack the top remaining free agents who are looking for new teams.","nowId":"1-39716609","allowComments":true,"images":[{"width":608,"height":342,"url":"https://a.espncdn.com/photo/2024/0115/r1277866_608x342_16-9.jpg","name":"Xavien Howard (Jan. 15, 2024) [608x342]","peers":[{"width":1296,"height":1296,"url":"https://a.espncdn.com/photo/2024/0115/r1277866_1296x1296_1-1.jpg","name":"Xavien Howard (Jan. 15, 2024) [1296x1296]"},{"width":1296,"height":729,"url":"https://a.espncdn.com/photo/2024/0115/r1277866_1296x729_16-9.jpg","name":"Xavien Howard (Jan. 15, 2024) [1296x729]"},{"width":864,"height":1296,"url":"https://a.espncdn.com/photo/2024/0115/r1277866_864x1296_2-3.jpg","name":"Xavien Howard (Jan. 15, 2024) [864x1296]"},{"width":1296,"height":864,"url":"https://a.espncdn.com/photo/2024/0115/r1277866_1296x864_3-2.jpg","name":"Xavien Howard (Jan. 15, 2024) [1296x864]"},{"width":1296,"height":518,"url":"https://a.espncdn.com/photo/2024/0115/r1277866_1296x518_5-2.jpg","name":"Xavien Howard (Jan. 15, 2024) [1296x518]"}]},{"width":608,"height":342,"alt":"Williams","url":"https://a.espncdn.com/photo/2020/1013/r759904_608x342_16-9.jpg","name":"Williams [608x342]","peers":[{"width":1296,"height":1296,"alt":"Williams","url":"https://a.espncdn.com/photo/2020/1013/r759904_1296x1296_1-1.jpg","name":"Williams [1296x1296]"},{"width":1296,"height":729,"alt":"Williams","url":"https://a.espncdn.com/photo/2020/1013/r759904_1296x729_16-9.jpg","name":"Williams [1296x729]"},{"width":864,"height":1296,"alt":"Williams","url":"https://a.espncdn.com/photo/2020/1013/r759904_864x1296_2-3.jpg","name":"Williams [864x1296]"},{"width":1296,"height":864,"alt":"Williams","url":"https://a.espncdn.com/photo/2020/1013/r759904_1296x864_3-2.jpg","name":"Williams [1296x864]"},{"width":1296,"height":518,"alt":"Williams","url":"https://a.espncdn.com/photo/2020/1013/r759904_1296x518_5-2.jpg","name":"Williams [1296x518]"}]},{"width":608,"height":342,"url":"https://a.espncdn.com/photo/2022/1012/r1074480_608x342_16-9.jpg","name":"Marquise Brown [608x342]","caption":"Marquise Brown caught eight of his 10 targets for 78 yards and a touchdown in Week 5, and his set up for a great matchup against the Seahawks in Week 6.","peers":[{"width":683,"height":683,"url":"https://a.espncdn.com/photo/2022/1012/r1074480_683x683_1-1.jpg","name":"Marquise Brown [683x683]","caption":"Marquise Brown caught eight of his 10 targets for 78 yards and a touchdown in Week 5, and his set up for a great matchup against the Seahawks in Week 6."},{"width":1024,"height":576,"url":"https://a.espncdn.com/photo/2022/1012/r1074480_1024x576_16-9.jpg","name":"Marquise Brown [1024x576]","caption":"Marquise Brown caught eight of his 10 targets for 78 yards and a touchdown in Week 5, and his set up for a great matchup against the Seahawks in Week 6."},{"width":455,"height":683,"url":"https://a.espncdn.com/photo/2022/1012/r1074480_455x683_2-3.jpg","name":"Marquise Brown [455x683]","caption":"Marquise Brown caught eight of his 10 targets for 78 yards and a touchdown in Week 5, and his set up for a great matchup against the Seahawks in Week 6."},{"width":1024,"height":683,"url":"https://a.espncdn.com/photo/2022/1012/r1074480_1024x683_3-2.jpg","name":"Marquise Brown [1024x683]","caption":"Marquise Brown caught eight of his 10 targets for 78 yards and a touchdown in Week 5, and his set up for a great matchup against the Seahawks in Week 6." ...

# %%
df.to_csv('results//player_outlook.csv', index=False)

# %%
##Load all the cs files from the folder and merge them into one file
import glob
import os
os.chdir('D:/Work/Github/nflfantasydraft/bot/documents/player_outlook')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
os.chdir('D:/Work/Github/nflfantasydraft/bot/documents/player_outlook')
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import pickle
import os
import random

class FantasyFootballDraftAssistant:
    def __init__(self):
        self.df = None
        self.positions = {'QB': (1, 2), 'RB': (6, 9), 'WR': (5, 9), 'TE': (1, 2), 'K': (1, 1), 'DST': (1, 1)}
        self.starting_positions = {'QB': 1, 'RB': 2, 'WR': 3, 'TE': 1, 'K': 1, 'DST': 1, 'FLEX': 1}
        self.flex_positions = ['RB', 'WR', 'TE']
        self.q_table = {}
        self.alpha = 0.1  # Learning rate
        self.gamma = 0.9  # Discount factor
        self.epsilon = 0.1  # Exploration rate
        self.total_episodes = 0
        self.base_exploration_N = 24  # Base number of top ADP players to consider during exploration
        self.position_exploration_factor = {
            'QB': 0.5, 'RB': 1.2, 'WR': 1.2, 'TE': 0.8, 'K': 0.3, 'DST': 0.3
        }
        self.epsilon_start = 0.2  # Starting exploration rate
        self.epsilon_end = 0.01  # Ending exploration rate
        self.epsilon_decay = 0.9999  # Decay rate for epsilon
        self.epsilon = self.epsilon_start

    def get_exploration_N(self, round_num, position):
        # Adjust exploration_N based on round number and position
        round_factor = min(2, 1 + (round_num - 1) * 0.1)  # Increase by 10% each round, up to 2x
        position_factor = self.position_exploration_factor.get(position, 1.0)
        return int(self.base_exploration_N * round_factor * position_factor)

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)  
        
    def load_data(self, file_path):
        self.df = pd.read_csv(file_path)
        self.df['ADP'] = pd.to_numeric(self.df['ADP'], errors='coerce')
        self.df = self.df.sort_values('ADP').reset_index(drop=True)
        self.players = self.df.to_dict('records')
        
    def get_state(self, team, round_num):
        pos_counts = [sum(1 for p in team if p['pos'] == pos) for pos in self.positions.keys()]
        return tuple(pos_counts + [round_num])
    
    def get_actions(self, available_players, team, round_num):
        actions = []
        for player in available_players:
            pos = player['pos']
            pos_count = sum(1 for p in team if p['pos'] == pos)
            if pos_count < self.positions[pos][1] and (pos not in ['K', 'DST'] or round_num > 12):
                actions.append(player['player'])
        return actions
    
    def calculate_team_value(self, team):
        weekly_scores = []
        for week in range(1, 18):  # 17-week season
            available_players = [p for p in team if p['bye_week'] != week]
            starters = self.select_starters(available_players)
            week_score = sum(p['ppr_projection'] / 17 for p in starters)
            weekly_scores.append(week_score)
        
        total_score = sum(weekly_scores)
        bench_strength = sum(p['ppr_projection'] for p in team) - sum(p['ppr_projection'] for p in self.select_starters(team))
        return total_score + (bench_strength * 0.1)  # Adding some value for bench strength
    
    def select_starters(self, available_players):
        starters = []
        for pos, count in self.starting_positions.items():
            if pos == 'FLEX':
                flex_options = sorted([p for p in available_players if p['pos'] in self.flex_positions and p not in starters], 
                                      key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(flex_options[:count])
            else:
                pos_players = sorted([p for p in available_players if p['pos'] == pos and p not in starters], 
                                     key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(pos_players[:count])
        return starters
    
    def calculate_reward(self, team, player, round_num):
        team_value_before = self.calculate_team_value(team)
        new_team = team + [player]
        team_value_after = self.calculate_team_value(new_team)
        value_added = team_value_after - team_value_before
        
        adp_bonus = max(0, (200 - player['ADP']) / 10) if not np.isnan(player['ADP']) else 0
        
        pos_counts = {pos: sum(1 for p in team if p['pos'] == pos) for pos in self.positions.keys()}
        
        # Prioritize key positions in early rounds
        if round_num <= 6:
            if player['pos'] == 'QB':
                if pos_counts['QB'] == 0:
                    value_added *= 1.5
                else:
                    value_added *= 0.5  # Penalize drafting a second QB early
            elif player['pos'] in ['RB', 'WR']:
                value_added *= 1.5
            elif player['pos'] == 'TE':
                if pos_counts['TE'] == 0:
                    value_added *= 1.5
                else:
                    value_added *= 0.5  # Penalize drafting a second TE early
        
        # Penalize drafting K and DST early
        if player['pos'] in ['K', 'DST'] and round_num <= 12:
            value_added *= 0.1
        
        # Boost value for filling starting lineup
        if pos_counts[player['pos']] < self.starting_positions.get(player['pos'], 0):
            value_added *= 1.5
        
        return value_added + adp_bonus
    
    def train(self, num_episodes=10000, num_teams=12):
        start_episode = self.total_episodes
        for episode in range(start_episode, start_episode + num_episodes):
            if episode % 1000 == 0:
                print(f"Training episode {episode}/{start_episode + num_episodes}")
            
            teams = [[] for _ in range(num_teams)]
            available_players = self.players.copy()
            
            for round_num in range(1, 19):
                for team_index in range(num_teams):
                    state = self.get_state(teams[team_index], round_num)
                    actions = self.get_actions(available_players, teams[team_index], round_num)
                    
                    if not actions:
                        continue
                    
                    if np.random.uniform(0, 1) < self.epsilon:
                        # Exploration: Choose randomly from top N ADP players
                        sorted_actions = sorted(actions, key=lambda a: next((p['ADP'] for p in available_players if p['player'] == a), float('inf')))
                        player = next(p for p in available_players if p['player'] == sorted_actions[0])
                        position = player['pos']
                        exploration_N = self.get_exploration_N(round_num, position)
                        top_N_adp = sorted_actions[:exploration_N]
                        action = np.random.choice(top_N_adp)
                    else:
                        # Exploitation: Choose the action with the highest Q-value
                        q_values = [self.q_table.get((state, a), 0) for a in actions]
                        action = actions[np.argmax(q_values)]
                    
                    player = next(p for p in available_players if p['player'] == action)
                    reward = self.calculate_reward(teams[team_index], player, round_num)
                    teams[team_index].append(player)
                    available_players = [p for p in available_players if p['player'] != action]
                    
                    next_state = self.get_state(teams[team_index], round_num + 1)
                    
                    # Q-value update
                    max_future_q = max([self.q_table.get((next_state, a), 0) for a in self.get_actions(available_players, teams[team_index], round_num + 1)], default=0)
                    current_q = self.q_table.get((state, action), 0)
                    new_q = (1 - self.alpha) * current_q + self.alpha * (reward + self.gamma * max_future_q)
                    self.q_table[(state, action)] = new_q
            
            # Decay epsilon after each episode
            self.decay_epsilon()
        
        self.total_episodes += num_episodes
    
    def recommend_players(self, team, available_players, round_num, num_recommendations=5):
        state = self.get_state(team, round_num)
        actions = self.get_actions(available_players, team, round_num)
        q_values = [(a, self.q_table.get((state, a), 0)) for a in actions]
        top_actions = sorted(q_values, key=lambda x: x[1], reverse=True)[:num_recommendations]
        player_dict = {p['player']: p for p in available_players}
        return [(player_dict[a], q) for a, q in top_actions]
    
    def simulate_draft(self, user_position, num_teams=12):
        teams = [[] for _ in range(num_teams)]
        available_players = self.players.copy()
        user_picks = []
        
        for round_num in range(1, 19):
            draft_order = range(num_teams) if round_num % 2 == 1 else reversed(range(num_teams))
            for pick_in_round, team_index in enumerate(draft_order):
                if team_index == user_position:
                    recommendations = self.recommend_players(teams[team_index], available_players, round_num)
                    user_picks.append(((round_num - 1) * num_teams + pick_in_round + 1, recommendations))
                    
                    if recommendations:
                        selected_player, _ = recommendations[0]
                        teams[team_index].append(selected_player)
                        available_players = [p for p in available_players if p['player'] != selected_player['player']]
                else:
                    # Other teams draft based on ADP with round-based randomness
                    valid_players = [p for p in available_players if sum(1 for player in teams[team_index] if player['pos'] == p['pos']) < self.positions[p['pos']][1]]
                    if valid_players:
                        # Sort valid players by ADP, handling NaN values
                        sorted_players = sorted(valid_players, key=lambda p: p['ADP'] if not np.isnan(p['ADP']) else float('inf'))
                        
                        # Determine the number of top players to consider based on the round
                        if round_num <= 1:
                            top_n = 2  # Pick the top ADP in rounds 1 and 2
                        elif round_num <= 3:
                            top_n = 2  # Pick from top 2 ADP in round 3
                        elif 4 <= round_num <= 6:
                            top_n = 3  # Pick from top 3 ADP in rounds 4, 5, 6
                        else:
                            top_n = 5  # Pick from top 5 ADP in later rounds
                        
                        # Select top N players (or fewer if less than N are available)
                        top_players = sorted_players[:min(top_n, len(sorted_players))]
                        
                        # Randomly select one player from the top players
                        player = random.choice(top_players)
                        teams[team_index].append(player)
                        available_players = [p for p in available_players if p['player'] != player['player']]
        
        return user_picks, teams
    
    def save_model(self, file_path):
        with open(file_path, 'wb') as f:
            pickle.dump((self.q_table, self.total_episodes), f)
        print(f"Model saved to {file_path}")
    
    def load_model(self, file_path):
        with open(file_path, 'rb') as f:
            self.q_table, self.total_episodes = pickle.load(f)
        print(f"Model loaded from {file_path}. Total episodes: {self.total_episodes}")

# %%
# Usage and testing
assistant = FantasyFootballDraftAssistant()
assistant.load_data('data//cbs_fantasy_projection_master.csv')

model_file = 'models//fantasy_football_modelV1.pkl'

# Check if a saved model exists
if os.path.exists(model_file):
    assistant.load_model(model_file)
    print("Continuing training from saved model...")
else:
    print("Starting new training...")

# Train for 10,000 episodes
print("Training the model...")
assistant.train(num_episodes=10000)

# Save the model after training
assistant.save_model(model_file)
# Out:
# Starting new training...
# Training the model...
# Training episode 0/10000
# Training episode 1000/10000
# Training episode 2000/10000
# Training episode 3000/10000
# Training episode 4000/10000
# Training episode 5000/10000
# Training episode 6000/10000
# Training episode 7000/10000
# Training episode 8000/10000
# Training episode 9000/10000
# Model saved to models//fantasy_football_modelV1.pkl

# %%
user_position=7
print(f"\nSimulating a draft for a user in position {user_position + 1}...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=user_position)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[user_position]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 8...
#
# Recommendations for your picks:
#
# Pick 8:
#   1. Saquon Barkley (RB) - Q-value: 341.37, ADP: 10.40
#   2. Jonathan Taylor (RB) - Q-value: 334.65, ADP: 11.20
#   3. Jahmyr Gibbs (RB) - Q-value: 332.60, ADP: 11.60
#   4. Kyren Williams (RB) - Q-value: 332.55, ADP: 16.00
#   5. Amon-Ra St. Brown (WR) - Q-value: 331.25, ADP: 6.80
#
# Pick 17:
#   1. Davante Adams (WR) - Q-value: 298.90, ADP: 18.40
#   2. Chris Olave (WR) - Q-value: 296.07, ADP: 23.40
#   3. Drake London (WR) - Q-value: 295.21, ADP: 25.20
#   4. Nico Collins (WR) - Q-value: 294.98, ADP: 32.80
#   5. Deebo Samuel (WR) - Q-value: 294.91, ADP: 33.00
#
# Pick 32:
#   1. Nico Collins (WR) - Q-value: 274.89, ADP: 32.80
#   2. Deebo Samuel (WR) - Q-value: 274.47, ADP: 33.00
#   3. Cooper Kupp (WR) - Q-value: 273.99, ADP: 38.20
#   4. DeVonta Smith (WR) - Q-value: 273.45, ADP: 43.40
#   5. Brandon Aiyuk (WR) - Q-value: 273.44, ADP: 32.80
#
# Pick 41:
#   1. Alvin Kamara (RB) - Q-value: 243.30, ADP: 39.60
#   2. Joe Mixon (RB) - Q-value: 242.95, ADP: 41.00
#   3. Dak Prescott (QB) - Q-value: 240.15, ADP: 68.40
#   4. C.J. Stroud (QB) - Q-value: 240.04, ADP: 47.60
#   5. Kenneth Walker III (RB) - Q-value: 238.86, ADP: 43.20
#
# Pick 56:
#   1. Joe Burrow (QB) - Q-value: 218.90, ADP: 60.00
#   2. Jordan Love (QB) - Q-value: 218.75, ADP: 74.20
#   3. Brock Purdy (QB) - Q-value: 215.36, ADP: 96.20
#   4. Kyler Murray (QB) - Q-value: 215.13, ADP: 75.60
#   5. Dak Prescott (QB) - Q-value: 215.11, ADP: 68.40
#
# Pick 65:
#   1. Christian Kirk (WR) - Q-value: 155.02, ADP: 71.20
#   2. Rashee Rice (WR) - Q-value: 154.10, ADP: 85.20
#   3. Ladd McConkey (WR) - Q-value: 153.94, ADP: 100.00
#   4. Calvin Ridley (WR) - Q-value: 153.94, ADP: 75.20
#   5. Terry McLaurin (WR) - Q-value: 153.93, ADP: 74.80
#
# Pick 80:
#   1. Jake Ferguson (TE) - Q-value: 123.23, ADP: 87.60
#   2. Brock Bowers (TE) - Q-value: 119.89, ADP: 102.40
#   3. Dallas Goedert (TE) - Q-value: 119.73, ADP: 112.40
#   4. Cole Kmet (TE) - Q-value: 119.18, ADP: 138.20
#   5. T.J. Hockenson (TE) - Q-value: 118.99, ADP: 116.20
#
# Pick 89:
#   1. Najee Harris (RB) - Q-value: 106.21, ADP: 75.80
#   2. Jaylen Warren (RB) - Q-value: 104.65, ADP: 87.60
#   3. Nick Chubb (RB) - Q-value: 104.37, ADP: 90.60
#   4. Austin Ekeler (RB) - Q-value: 104.14, ADP: 89.80
#   5. Brian Robinson Jr. (RB) - Q-value: 103.83, ADP: 97.40
#
# Pick 104:
#   1. Keon Coleman (WR) - Q-value: 89.58, ADP: 103.20
#   2. Jaxon Smith-Njigba (WR) - Q-value: 89.37, ADP: 106.00
#   3. Rome Odunze (WR) - Q-value: 89.24, ADP: 104.00
#   4. Courtland Sutton (WR) - Q-value: 88.26, ADP: 119.80
#   5. Brian Thomas Jr. (WR) - Q-value: 87.47, ADP: 124.00
#
# Pick 113:
#   1. Jayden Daniels (QB) - Q-value: 84.01, ADP: 109.40
#   2. Jared Goff (QB) - Q-value: 83.80, ADP: 118.00
#   3. Caleb Williams (QB) - Q-value: 83.36, ADP: 117.80
#   4. Tua Tagovailoa (QB) - Q-value: 83.26, ADP: 115.60
#   5. Justin Herbert (QB) - Q-value: 82.23, ADP: 128.80
#
# Pick 128:
#   1. Curtis Samuel (WR) - Q-value: 72.32, ADP: 136.20
#   2. Khalil Shakir (WR) - Q-value: 72.16, ADP: 139.60
#   3. Mike Williams (WR) - Q-value: 72.08, ADP: 143.80
#   4. Romeo Doubs (WR) - Q-value: 72.00, ADP: 142.60
#   5. Jakobi Meyers (WR) - Q-value: 71.68, ADP: 146.20
#
# Pick 137:
#   1. Chuba Hubbard (RB) - Q-value: 67.02, ADP: 150.80
#   2. Rico Dowdle (RB) - Q-value: 66.53, ADP: 159.60
#   3. Tyler Allgeier (RB) - Q-value: 66.16, ADP: 160.80
#   4. Ty Chandler (RB) - Q-value: 65.44, ADP: 161.80
#   5. MarShawn Lloyd (RB) - Q-value: 65.32, ADP: 163.60
#
# Pick 152:
#   1. KC (DST) - Q-value: 60.13, ADP: 140.00
#   2. MIA (DST) - Q-value: 57.83, ADP: 141.00
#   3. PHI (DST) - Q-value: 54.68, ADP: 175.00
#   4. Jake Elliott (K) - Q-value: 54.39, ADP: 145.00
#   5. BUF (DST) - Q-value: 53.56, ADP: 174.00
#
# Pick 161:
#   1. Jake Elliott (K) - Q-value: 35.17, ADP: 145.00
#   2. Jake Moody (K) - Q-value: 31.54, ADP: 167.60
#   3. Dustin Hopkins (K) - Q-value: 31.34, ADP: 168.00
#   4. Greg Zuerlein (K) - Q-value: 30.62, ADP: 183.30
#   5. Tyler Bass (K) - Q-value: 30.62, ADP: 186.80
#
# Pick 176:
#   1. Isaiah Likely (TE) - Q-value: 14.45, ADP: 190.20
#   2. Hunter Henry (TE) - Q-value: 13.59, ADP: 194.00
#   3. Tyler Conklin (TE) - Q-value: 13.40, ADP: 204.80
#   4. Ben Sinnott (TE) - Q-value: 13.40, ADP: 220.80
#   5. Chigoziem Okonkwo (TE) - Q-value: 13.32, ADP: 207.00
#
# Pick 185:
#   1. Jahan Dotson (WR) - Q-value: 7.61, ADP: 187.00
#   2. Bucky Irving (RB) - Q-value: 5.77, ADP: 207.00
#   3. Michael Wilson (WR) - Q-value: 5.77, ADP: 205.80
#   4. Tyrone Tracy Jr. (RB) - Q-value: 5.77, ADP: 203.60
#   5. Braelon Allen (RB) - Q-value: 5.76, ADP: 215.00
#
# Pick 200:
#   1. Kendrick Bourne (WR) - Q-value: 2.33, ADP: 279.00
#   2. Wan'Dale Robinson (WR) - Q-value: 2.29, ADP: 216.50
#   3. Tim Patrick (WR) - Q-value: 2.07, ADP: 356.00
#   4. D'Onta Foreman (RB) - Q-value: 2.07, ADP: 242.50
#   5. A.T. Perry (WR) - Q-value: 2.06, ADP: 356.70
#
# Pick 209:
#   1. Carson Steele (RB) - Q-value: 1.28, ADP: 709.00
#   2. D'Onta Foreman (RB) - Q-value: 0.92, ADP: 242.50
#   3. Tim Patrick (WR) - Q-value: 0.92, ADP: 356.00
#   4. Darius Slayton (WR) - Q-value: 0.85, ADP: 299.50
#   5. DJ Chark (WR) - Q-value: 0.85, ADP: 311.30
#
# Your team:
# Saquon Barkley (RB) - ADP: 10.40, Projection: 19.96
# Davante Adams (WR) - ADP: 18.40, Projection: 15.29
# Nico Collins (WR) - ADP: 32.80, Projection: 14.88
# Alvin Kamara (RB) - ADP: 39.60, Projection: 14.76
# Joe Burrow (QB) - ADP: 60.00, Projection: 22.34
# Christian Kirk (WR) - ADP: 71.20, Projection: 12.61
# Jake Ferguson (TE) - ADP: 87.60, Projection: 11.14
# Najee Harris (RB) - ADP: 75.80, Projection: 11.66
# Keon Coleman (WR) - ADP: 103.20, Projection: 11.14
# Jayden Daniels (QB) - ADP: 109.40, Projection: 20.35
# Curtis Samuel (WR) - ADP: 136.20, Projection: 9.20
# Chuba Hubbard (RB) - ADP: 150.80, Projection: 7.44
# KC (DST) - ADP: 140.00, Projection: 13.21
# Jake Elliott (K) - ADP: 145.00, Projection: 8.59
# Isaiah Likely (TE) - ADP: 190.20, Projection: 8.36
# Jahan Dotson (WR) - ADP: 187.00, Projection: 8.98
# Kendrick Bourne (WR) - ADP: 279.00, Projection: 10.71
# Carson Steele (RB) - ADP: 709.00, Projection: 10.99
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 5, 'WR': 8, 'TE': 1, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 9, 'WR': 3, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 7, 'WR': 6, 'TE': 1, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 217.87
# Team 2: 216.17
# Team 3: 220.78
# Team 4: 217.84
# Team 5: 225.86
# Team 6: 220.82
# Team 7: 217.74
# Team 8: 231.61
# Team 9: 218.17
# Team 10: 201.31
# Team 11: 216.16
# Team 12: 218.10

# %%
user_position=0
print(f"\nSimulating a draft for a user in position {user_position}...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=user_position)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[user_position]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 0...
#
# Recommendations for your picks:
#
# Pick 1:
#   1. CeeDee Lamb (WR) - Q-value: 257.48, ADP: 2.00
#   2. Tyreek Hill (WR) - Q-value: 255.71, ADP: 3.20
#   3. Amon-Ra St. Brown (WR) - Q-value: 254.56, ADP: 6.80
#   4. Justin Jefferson (WR) - Q-value: 254.08, ADP: 6.00
#   5. Ja'Marr Chase (WR) - Q-value: 252.79, ADP: 5.80
#
# Pick 24:
#   1. Drake London (WR) - Q-value: 235.08, ADP: 25.20
#   2. Nico Collins (WR) - Q-value: 234.90, ADP: 32.80
#   3. Deebo Samuel (WR) - Q-value: 234.61, ADP: 33.00
#   4. Mike Evans (WR) - Q-value: 234.34, ADP: 30.80
#   5. Cooper Kupp (WR) - Q-value: 234.11, ADP: 38.20
#
# Pick 25:
#   1. Jalen Hurts (QB) - Q-value: 223.78, ADP: 31.80
#   2. Josh Allen (QB) - Q-value: 223.31, ADP: 26.20
#   3. Patrick Mahomes (QB) - Q-value: 221.06, ADP: 29.60
#   4. Lamar Jackson (QB) - Q-value: 219.69, ADP: 37.60
#   5. C.J. Stroud (QB) - Q-value: 217.10, ADP: 47.60
#
# Pick 48:
#   1. George Kittle (TE) - Q-value: 196.57, ADP: 59.00
#   2. David Njoku (TE) - Q-value: 194.76, ADP: 82.40
#   3. Brock Bowers (TE) - Q-value: 190.65, ADP: 102.40
#   4. T.J. Hockenson (TE) - Q-value: 189.35, ADP: 116.20
#   5. Dalton Schultz (TE) - Q-value: 187.70, ADP: 129.20
#
# Pick 49:
#   1. Trey McBride (TE) - Q-value: 190.87, ADP: 46.60
#   2. Dalton Kincaid (TE) - Q-value: 190.62, ADP: 52.20
#   3. Evan Engram (TE) - Q-value: 189.28, ADP: 65.60
#   4. Kyle Pitts (TE) - Q-value: 188.46, ADP: 61.20
#   5. Jake Ferguson (TE) - Q-value: 186.30, ADP: 87.60
#
# Pick 72:
#   1. Chris Godwin (WR) - Q-value: 179.24, ADP: 76.00
#   2. Calvin Ridley (WR) - Q-value: 179.23, ADP: 75.20
#   3. Terry McLaurin (WR) - Q-value: 178.94, ADP: 74.80
#   4. Rashee Rice (WR) - Q-value: 178.34, ADP: 85.20
#   5. Marquise Brown (WR) - Q-value: 177.45, ADP: 90.00
#
# Pick 73:
#   1. Jared Goff (QB) - Q-value: 172.53, ADP: 118.00
#   2. Jayden Daniels (QB) - Q-value: 172.23, ADP: 109.40
#   3. Caleb Williams (QB) - Q-value: 171.38, ADP: 117.80
#   4. Tua Tagovailoa (QB) - Q-value: 171.37, ADP: 115.60
#   5. Trevor Lawrence (QB) - Q-value: 170.67, ADP: 133.20
#
# Pick 96:
#   1. Brian Robinson Jr. (RB) - Q-value: 155.35, ADP: 97.40
#   2. Javonte Williams (RB) - Q-value: 154.83, ADP: 97.20
#   3. Gus Edwards (RB) - Q-value: 154.54, ADP: 112.20
#   4. Chase Brown (RB) - Q-value: 153.68, ADP: 120.80
#   5. Trey Benson (RB) - Q-value: 153.60, ADP: 121.80
#
# Pick 97:
#   1. Devin Singletary (RB) - Q-value: 125.59, ADP: 98.60
#   2. Chase Brown (RB) - Q-value: 125.22, ADP: 120.80
#   3. Javonte Williams (RB) - Q-value: 125.21, ADP: 97.20
#   4. Ezekiel Elliott (RB) - Q-value: 125.19, ADP: 108.40
#   5. Tyjae Spears (RB) - Q-value: 125.01, ADP: 103.20
#
# Pick 120:
#   1. Blake Corum (RB) - Q-value: 105.08, ADP: 123.20
#   2. Chase Brown (RB) - Q-value: 104.45, ADP: 120.80
#   3. Jerome Ford (RB) - Q-value: 104.26, ADP: 124.60
#   4. J.K. Dobbins (RB) - Q-value: 104.20, ADP: 133.60
#   5. Trey Benson (RB) - Q-value: 104.12, ADP: 121.80
#
# Pick 121:
#   1. Josh Downs (WR) - Q-value: 76.42, ADP: 184.00
#   2. Curtis Samuel (WR) - Q-value: 76.23, ADP: 136.20
#   3. Josh Palmer (WR) - Q-value: 76.18, ADP: 158.80
#   4. Jerry Jeudy (WR) - Q-value: 76.12, ADP: 147.00
#   5. Kendrick Bourne (WR) - Q-value: 76.11, ADP: 279.00
#
# Pick 144:
#   1. Jakobi Meyers (WR) - Q-value: 65.32, ADP: 146.20
#   2. Mike Williams (WR) - Q-value: 65.15, ADP: 143.80
#   3. Jerry Jeudy (WR) - Q-value: 64.63, ADP: 147.00
#   4. Josh Palmer (WR) - Q-value: 64.61, ADP: 158.80
#   5. Brandin Cooks (WR) - Q-value: 64.18, ADP: 160.60
#
# Pick 145:
#   1. MIA (DST) - Q-value: 55.78, ADP: 141.00
#   2. BUF (DST) - Q-value: 50.84, ADP: 174.00
#   3. CHI (DST) - Q-value: 50.47, ADP: 178.00
#   4. TEN (DST) - Q-value: 50.12, ADP: 230.00
#   5. LAC (DST) - Q-value: 50.09, ADP: 179.00
#
# Pick 168:
#   1. Miles Sanders (RB) - Q-value: 25.06, ADP: 252.00
#   2. Chase Edmonds (RB) - Q-value: 24.93, ADP: 462.00
#   3. Kendre Miller (RB) - Q-value: 24.75, ADP: 178.40
#   4. Cody Schrader (RB) - Q-value: 24.73, ADP: 718.00
#   5. Emari Demercado (RB) - Q-value: 24.72, ADP: 443.00
#
# Pick 169:
#   1. Jaleel McLaughlin (RB) - Q-value: 12.71, ADP: 174.40
#   2. Dontayvion Wicks (WR) - Q-value: 12.18, ADP: 186.00
#   3. Rasheen Ali (RB) - Q-value: 12.17, ADP: 376.00
#   4. Deuce Vaughn (RB) - Q-value: 12.07, ADP: 326.00
#   5. Jahan Dotson (WR) - Q-value: 11.96, ADP: 187.00
#
# Pick 192:
#   1. Nyheim Hines (RB) - Q-value: 3.92, ADP: 463.00
#   2. Kenneth Gainwell (RB) - Q-value: 3.82, ADP: 236.30
#   3. Carson Steele (RB) - Q-value: 3.79, ADP: 709.00
#   4. Bucky Irving (RB) - Q-value: 3.77, ADP: 207.00
#   5. Cody Schrader (RB) - Q-value: 3.76, ADP: 718.00
#
# Pick 193:
#   1. Wan'Dale Robinson (WR) - Q-value: 2.26, ADP: 216.50
#   2. Kendrick Bourne (WR) - Q-value: 2.25, ADP: 279.00
#   3. Carson Steele (RB) - Q-value: 2.25, ADP: 709.00
#   4. Demario Douglas (WR) - Q-value: 2.12, ADP: 201.80
#   5. Tim Patrick (WR) - Q-value: 1.77, ADP: 356.00
#
# Pick 216:
#   1. Kendrick Bourne (WR) - Q-value: 1.17, ADP: 279.00
#   2. Carson Steele (RB) - Q-value: 1.16, ADP: 709.00
#   3. Tim Patrick (WR) - Q-value: 0.94, ADP: 356.00
#   4. D'Onta Foreman (RB) - Q-value: 0.90, ADP: 242.50
#   5. DJ Chark (WR) - Q-value: 0.87, ADP: 311.30
#
# Your team:
# CeeDee Lamb (WR) - ADP: 2.00, Projection: 20.90
# Drake London (WR) - ADP: 25.20, Projection: 14.37
# Jalen Hurts (QB) - ADP: 31.80, Projection: 26.95
# George Kittle (TE) - ADP: 59.00, Projection: 11.45
# Trey McBride (TE) - ADP: 46.60, Projection: 11.94
# Chris Godwin (WR) - ADP: 76.00, Projection: 12.32
# Jared Goff (QB) - ADP: 118.00, Projection: 21.01
# Brian Robinson Jr. (RB) - ADP: 97.40, Projection: 11.35
# Devin Singletary (RB) - ADP: 98.60, Projection: 9.81
# Blake Corum (RB) - ADP: 123.20, Projection: 8.69
# Josh Downs (WR) - ADP: 184.00, Projection: 6.34
# Jakobi Meyers (WR) - ADP: 146.20, Projection: 10.72
# MIA (DST) - ADP: 141.00, Projection: 11.66
# Miles Sanders (RB) - ADP: 252.00, Projection: 6.55
# Jaleel McLaughlin (RB) - ADP: 174.40, Projection: 7.35
# Nyheim Hines (RB) - ADP: 463.00, Projection: 2.27
# Wan'Dale Robinson (WR) - ADP: 216.50, Projection: 10.35
# Kendrick Bourne (WR) - ADP: 279.00, Projection: 10.71
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 2, 'K': 0, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 8, 'WR': 4, 'TE': 2, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 9, 'WR': 4, 'TE': 1, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 214.75
# Team 2: 228.58
# Team 3: 223.33
# Team 4: 213.29
# Team 5: 216.72
# Team 6: 214.30
# Team 7: 223.11
# Team 8: 204.64
# Team 9: 220.98
# Team 10: 218.09
# Team 11: 217.05
# Team 12: 213.98
