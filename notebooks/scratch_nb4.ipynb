# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import pickle
import os
import random

class FantasyFootballDraftAssistant:
    def __init__(self):
        self.df = None
        self.positions = {'QB': (1, 2), 'RB': (6, 9), 'WR': (5, 9), 'TE': (1, 2), 'K': (1, 1), 'DST': (1, 1)}
        self.starting_positions = {'QB': 1, 'RB': 2, 'WR': 3, 'TE': 1, 'K': 1, 'DST': 1, 'FLEX': 1}
        self.flex_positions = ['RB', 'WR', 'TE']
        self.q_table = {}
        self.alpha = 0.1  # Learning rate
        self.gamma = 0.9  # Discount factor
        self.epsilon = 0.1  # Exploration rate
        self.total_episodes = 0
        self.base_exploration_N = 15  # Maximum exploration cap
        self.min_exploration_N = 5    # Minimum exploration, even in late rounds
        self.position_exploration_factor = {
            'QB': 0.7, 'RB': 1.2, 'WR': 1.2, 'TE': 0.9, 'K': 0.3, 'DST': 0.3
        }

        self.epsilon_start = 0.2  # Starting exploration rate
        self.epsilon_end = 0.01  # Ending exploration rate
        self.epsilon_decay = 0.9999  # Decay rate for epsilon
        self.epsilon = self.epsilon_start
        self.num_teams = 12

    def get_exploration_N(self, round_num, position):
        # Dynamic round factor: starts high, decreases as draft progresses
        round_factor = max(0.5, 2 - (round_num - 1) * 0.1)  # Starts at 2, decreases by 0.1 each round, min 0.5
        
        # Apply position factor
        position_factor = self.position_exploration_factor.get(position, 1.0)
        
        # Calculate exploration N
        exploration_N = int(self.base_exploration_N * round_factor * position_factor)
        
        # Ensure N is within our defined range
        return max(self.min_exploration_N, min(exploration_N, self.base_exploration_N))

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)  
        
    def load_data(self, file_path):
        self.df = pd.read_csv(file_path)
        self.df['ADP'] = pd.to_numeric(self.df['ADP'], errors='coerce')
        self.df = self.df.sort_values('ADP').reset_index(drop=True)
        self.players = self.df.to_dict('records')
        
    def get_state(self, team, round_num, pick_number):
        pos_counts = [sum(1 for p in team if p['pos'] == pos) for pos in self.positions.keys()]
        return tuple(pos_counts + [round_num, pick_number])
    
    def get_actions(self, available_players, team, round_num):
        actions = []
        for player in available_players:
            pos = player['pos']
            pos_count = sum(1 for p in team if p['pos'] == pos)
            if pos_count < self.positions[pos][1] and (pos not in ['K', 'DST'] or round_num > 12):
                actions.append(player['player'])
        return actions
    
    def calculate_team_value(self, team):
        weekly_scores = []
        for week in range(1, 18):  # 17-week season
            available_players = [p for p in team if p['bye_week'] != week]
            starters = self.select_starters(available_players)
            week_score = sum(p['ppr_projection'] / 17 for p in starters)
            weekly_scores.append(week_score)
        
        total_score = sum(weekly_scores)
        bench_strength = sum(p['ppr_projection'] for p in team) - sum(p['ppr_projection'] for p in self.select_starters(team))
        return total_score + (bench_strength * 0.1)  # Adding some value for bench strength
    
    def select_starters(self, available_players):
        starters = []
        for pos, count in self.starting_positions.items():
            if pos == 'FLEX':
                flex_options = sorted([p for p in available_players if p['pos'] in self.flex_positions and p not in starters], 
                                      key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(flex_options[:count])
            else:
                pos_players = sorted([p for p in available_players if p['pos'] == pos and p not in starters], 
                                     key=lambda x: x['ppr_projection'], reverse=True)
                starters.extend(pos_players[:count])
        return starters
    
    def calculate_reward(self, team, player, round_num):
        team_value_before = self.calculate_team_value(team)
        new_team = team + [player]
        team_value_after = self.calculate_team_value(new_team)
        value_added = team_value_after - team_value_before
        
        adp_bonus = max(0, (200 - player['ADP']) / 10) if not np.isnan(player['ADP']) else 0
        
        pos_counts = {pos: sum(1 for p in team if p['pos'] == pos) for pos in self.positions.keys()}
        
        # Prioritize key positions in early rounds
        if round_num <= 6:
            if player['pos'] == 'QB':
                if pos_counts['QB'] == 0:
                    value_added *= 1.5
                else:
                    value_added *= 0.5  # Penalize drafting a second QB early
            elif player['pos'] in ['RB', 'WR']:
                value_added *= 1.5
            elif player['pos'] == 'TE':
                if pos_counts['TE'] == 0:
                    value_added *= 1.5
                else:
                    value_added *= 0.5  # Penalize drafting a second TE early
        
        # Penalize drafting K and DST early
        if player['pos'] in ['K', 'DST'] and round_num <= 12:
            value_added *= 0.1
        
        # Boost value for filling starting lineup
        if pos_counts[player['pos']] < self.starting_positions.get(player['pos'], 0):
            value_added *= 1.5
        
        return value_added + adp_bonus
    
    def train(self, num_episodes=10000):
        start_episode = self.total_episodes
        for episode in range(start_episode, start_episode + num_episodes):
            if episode % 200 == 0:
                print(f"Training episode {episode}/{start_episode + num_episodes}")
            
            user_position = random.randint(0, self.num_teams - 1)  # Randomize user position for each episode
            teams = [[] for _ in range(self.num_teams)]
            available_players = self.players.copy()
            
            for round_num in range(1, 19):
                draft_order = range(self.num_teams) if round_num % 2 == 1 else reversed(range(self.num_teams))
                for pick_in_round, team_index in enumerate(draft_order):
                    pick_number = (round_num - 1) * self.num_teams + pick_in_round + 1
                    state = self.get_state(teams[team_index], round_num, pick_number)
                    actions = self.get_actions(available_players, teams[team_index], round_num)
                    
                    if not actions:
                        continue
                    
                    if np.random.uniform(0, 1) < self.epsilon:
                        # Exploration: Choose randomly from top N ADP players
                        sorted_actions = sorted(actions, key=lambda a: next((p['ADP'] for p in available_players if p['player'] == a), float('inf')))
                        player = next(p for p in available_players if p['player'] == sorted_actions[0])
                        position = player['pos']
                        exploration_N = self.get_exploration_N(round_num, position)
                        top_N_adp = sorted_actions[:exploration_N]
                        action = np.random.choice(top_N_adp)
                    else:
                        # Exploitation: Choose the action with the highest Q-value
                        q_values = [self.q_table.get((state, a), 0) for a in actions]
                        action = actions[np.argmax(q_values)]
                    
                    player = next(p for p in available_players if p['player'] == action)
                    reward = self.calculate_reward(teams[team_index], player, round_num)
                    teams[team_index].append(player)
                    available_players = [p for p in available_players if p['player'] != action]
                    
                    next_round = round_num + 1 if pick_in_round == self.num_teams - 1 else round_num
                    next_pick = (pick_number % self.num_teams) + 1
                    next_state = self.get_state(teams[team_index], next_round, next_pick)
                    
                    # Q-value update
                    max_future_q = max([self.q_table.get((next_state, a), 0) for a in self.get_actions(available_players, teams[team_index], next_round)], default=0)
                    current_q = self.q_table.get((state, action), 0)
                    new_q = (1 - self.alpha) * current_q + self.alpha * (reward + self.gamma * max_future_q)
                    self.q_table[(state, action)] = new_q
            
            # Decay epsilon after each episode
            self.decay_epsilon()
        
        self.total_episodes += num_episodes
    
    def recommend_players(self, team, available_players, round_num,pick_number, num_recommendations=5):
        state = self.get_state(team, round_num, pick_number)
        actions = self.get_actions(available_players, team, round_num)
        q_values = [(a, self.q_table.get((state, a), 0)) for a in actions]
        top_actions = sorted(q_values, key=lambda x: x[1], reverse=True)[:num_recommendations]
        player_dict = {p['player']: p for p in available_players}
        return [(player_dict[a], q) for a, q in top_actions]
    
    def simulate_draft(self, user_position, num_teams=12):
        teams = [[] for _ in range(num_teams)]
        available_players = self.players.copy()
        user_picks = []
        
        for round_num in range(1, 19):
            draft_order = range(self.num_teams) if round_num % 2 == 1 else reversed(range(self.num_teams))
            for pick_in_round, team_index in enumerate(draft_order):
                pick_number = (round_num - 1) * self.num_teams + pick_in_round + 1
                if team_index == user_position:
                    recommendations = self.recommend_players(teams[team_index], available_players, round_num, pick_number)
                    user_picks.append((pick_number, recommendations))
                    
                    if recommendations:
                        selected_player, _ = recommendations[0]
                        teams[team_index].append(selected_player)
                        available_players = [p for p in available_players if p['player'] != selected_player['player']]
                else:
                    # Other teams draft based on ADP with round-based randomness
                    valid_players = [p for p in available_players if sum(1 for player in teams[team_index] if player['pos'] == p['pos']) < self.positions[p['pos']][1]]
                    if valid_players:
                        # Sort valid players by ADP, handling NaN values
                        sorted_players = sorted(valid_players, key=lambda p: p['ADP'] if not np.isnan(p['ADP']) else float('inf'))
                        
                        # Determine the number of top players to consider based on the round
                        if round_num <= 1:
                            top_n = 2  # Pick the top ADP in rounds 1 and 2
                        elif round_num <= 3:
                            top_n = 2  # Pick from top 2 ADP in round 3
                        elif 4 <= round_num <= 6:
                            top_n = 3  # Pick from top 3 ADP in rounds 4, 5, 6
                        else:
                            top_n = 5  # Pick from top 5 ADP in later rounds
                        
                        # Select top N players (or fewer if less than N are available)
                        top_players = sorted_players[:min(top_n, len(sorted_players))]
                        
                        # Randomly select one player from the top players
                        player = random.choice(top_players)
                        teams[team_index].append(player)
                        available_players = [p for p in available_players if p['player'] != player['player']]
        
        return user_picks, teams
    
    def save_model(self, file_path):
        with open(file_path, 'wb') as f:
            pickle.dump((self.q_table, self.total_episodes), f)
        print(f"Model saved to {file_path}")
    
    def load_model(self, file_path):
        with open(file_path, 'rb') as f:
            self.q_table, self.total_episodes = pickle.load(f)
        print(f"Model loaded from {file_path}. Total episodes: {self.total_episodes}")

# %%
# Usage and testing
assistant = FantasyFootballDraftAssistant()
assistant.load_data('data//cbs_fantasy_projection_master.csv')

model_file = 'models//fantasy_football_model.pkl'

# Check if a saved model exists
if os.path.exists(model_file):
    assistant.load_model(model_file)
    print("Continuing training from saved model...")
else:
    print("Starting new training...")

# Train for 10,000 episodes
print("Training the model...")
assistant.train(num_episodes=50000)

# Save the model after training
assistant.save_model(model_file)
# Out:
# Model loaded from models//fantasy_football_model.pkl. Total episodes: 60000
# Continuing training from saved model...
# Training the model...
# Training episode 60000/110000
# Training episode 60200/110000
# Training episode 60400/110000
# Training episode 60600/110000
# Training episode 60800/110000
# Training episode 61000/110000
# Training episode 61200/110000
# Training episode 61400/110000
# Training episode 61600/110000
# Training episode 61800/110000
# Training episode 62000/110000
# Training episode 62200/110000
# Training episode 62400/110000
# Training episode 62600/110000
# Training episode 62800/110000
# Training episode 63000/110000
# Training episode 63200/110000
# Training episode 63400/110000
# Training episode 63600/110000
# Training episode 63800/110000
# Training episode 64000/110000
# Training episode 64200/110000
# Training episode 64400/110000
# Training episode 64600/110000
# Training episode 64800/110000
# Training episode 65000/110000
# Training episode 65200/110000
# Training episode 65400/110000
# Training episode 65600/110000
# Training episode 65800/110000
# Training episode 66000/110000
# Training episode 66200/110000
# Training episode 66400/110000
# Training episode 66600/110000
# Training episode 66800/110000
# Training episode 67000/110000
# Training episode 67200/110000
# Training episode 67400/110000
# Training episode 67600/110000
# Training episode 67800/110000
# Training episode 68000/110000
# Training episode 68200/110000
# Training episode 68400/110000
# Training episode 68600/110000
# Training episode 68800/110000
# Training episode 69000/110000
# Training episode 69200/110000
# Training episode 69400/110000
# Training episode 69600/110000
# Training episode 69800/110000
# Training episode 70000/110000
# Training episode 70200/110000
# Training episode 70400/110000
# Training episode 70600/110000
# Training episode 70800/110000
# Training episode 71000/110000
# Training episode 71200/110000
# Training episode 71400/110000
# Training episode 71600/110000
# Training episode 71800/110000
# Training episode 72000/110000
# Training episode 72200/110000
# Training episode 72400/110000
# Training episode 72600/110000
# Training episode 72800/110000
# Training episode 73000/110000
# Training episode 73200/110000
# Training episode 73400/110000
# Training episode 73600/110000
# Training episode 73800/110000
# Training episode 74000/110000
# Training episode 74200/110000
# Training episode 74400/110000
# Training episode 74600/110000
# Training episode 74800/110000
# Training episode 75000/110000
# Training episode 75200/110000
# Training episode 75400/110000
# Training episode 75600/110000
# Training episode 75800/110000
# Training episode 76000/110000
# Training episode 76200/110000
# Training episode 76400/110000
# Training episode 76600/110000
# Training episode 76800/110000
# Training episode 77000/110000
# Training episode 77200/110000
# Training episode 77400/110000
# Training episode 77600/110000
# Training episode 77800/110000
# Training episode 78000/110000
# Training episode 78200/110000
# Training episode 78400/110000
# Training episode 78600/110000
# Training episode 78800/110000
# Training episode 79000/110000
# Training episode 79200/110000
# Training episode 79400/110000
# Training episode 79600/110000
# Training episode 79800/110000
# Training episode 80000/110000
# Training episode 80200/110000
# Training episode 80400/110000
# Training episode 80600/110000
# Training episode 80800/110000
# Training episode 81000/110000
# Training episode 81200/110000
# Training episode 81400/110000
# Training episode 81600/110000
# Training episode 81800/110000
# Training episode 82000/110000
# Training episode 82200/110000
# Training episode 82400/110000
# Training episode 82600/110000
# Training episode 82800/110000
# Training episode 83000/110000
# Training episode 83200/110000
# Training episode 83400/110000
# Training episode 83600/110000
# Training episode 83800/110000
# Training episode 84000/110000
# Training episode 84200/110000
# Training episode 84400/110000
# Training episode 84600/110000
# Training episode 84800/110000
# Training episode 85000/110000
# Training episode 85200/110000
# Training episode 85400/110000
# Training episode 85600/110000
# Training episode 85800/110000
# Training episode 86000/110000
# Training episode 86200/110000
# Training episode 86400/110000
# Training episode 86600/110000
# Training episode 86800/110000
# Training episode 87000/110000
# Training episode 87200/110000
# Training episode 87400/110000
# Training episode 87600/110000
# Training episode 87800/110000
# Training episode 88000/110000
# Training episode 88200/110000
# Training episode 88400/110000
# Training episode 88600/110000
# Training episode 88800/110000
# Training episode 89000/110000
# Training episode 89200/110000
# Training episode 89400/110000
# Training episode 89600/110000
# Training episode 89800/110000
# Training episode 90000/110000
# Training episode 90200/110000
# Training episode 90400/110000
# Training episode 90600/110000
# Training episode 90800/110000
# Training episode 91000/110000
# Training episode 91200/110000
# Training episode 91400/110000
# Training episode 91600/110000
# Training episode 91800/110000
# Training episode 92000/110000
# Training episode 92200/110000
# Training episode 92400/110000
# Training episode 92600/110000
# Training episode 92800/110000
# Training episode 93000/110000
# Training episode 93200/110000
# Training episode 93400/110000
# Training episode 93600/110000
# Training episode 93800/110000
# Training episode 94000/110000
# Training episode 94200/110000
# Training episode 94400/110000
# Training episode 94600/110000
# Training episode 94800/110000
# Training episode 95000/110000
# Training episode 95200/110000
# Training episode 95400/110000
# Training episode 95600/110000
# Training episode 95800/110000
# Training episode 96000/110000
# Training episode 96200/110000
# Training episode 96400/110000
# Training episode 96600/110000
# Training episode 96800/110000
# Training episode 97000/110000
# Training episode 97200/110000
# Training episode 97400/110000
# Training episode 97600/110000
# Training episode 97800/110000
# Training episode 98000/110000
# Training episode 98200/110000
# Training episode 98400/110000
# Training episode 98600/110000
# Training episode 98800/110000
# Training episode 99000/110000
# Training episode 99200/110000
# Training episode 99400/110000
# Training episode 99600/110000
# Training episode 99800/110000
# Training episode 100000/110000
# Training episode 100200/110000
# Training episode 100400/110000
# Training episode 100600/110000
# Training episode 100800/110000
# Training episode 101000/110000
# Training episode 101200/110000
# Training episode 101400/110000
# Training episode 101600/110000
# Training episode 101800/110000
# Training episode 102000/110000
# Training episode 102200/110000
# Training episode 102400/110000
# Training episode 102600/110000
# Training episode 102800/110000
# Training episode 103000/110000
# Training episode 103200/110000
# Training episode 103400/110000
# Training episode 103600/110000
# Training episode 103800/110000
# Training episode 104000/110000
# Training episode 104200/110000
# Training episode 104400/110000
# Training episode 104600/110000
# Training episode 104800/110000
# Training episode 105000/110000
# Training episode 105200/110000
# Training episode 105400/110000
# Training episode 105600/110000
# Training episode 105800/110000
# Training episode 106000/110000
# Training episode 106200/110000
# Training episode 106400/110000
# Training episode 106600/110000
# Training episode 106800/110000
# Training episode 107000/110000
# Training episode 107200/110000
# Training episode 107400/110000
# Training episode 107600/110000
# Training episode 107800/110000
# Training episode 108000/110000
# Training episode 108200/110000
# Training episode 108400/110000
# Training episode 108600/110000
# Training episode 108800/110000
# Training episode 109000/110000
# Training episode 109200/110000
# Training episode 109400/110000
# Training episode 109600/110000
# Training episode 109800/110000
# Model saved to models//fantasy_football_model.pkl

# %%
user_position=7
print(f"\nSimulating a draft for a user in position {user_position + 1}...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=user_position)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[user_position]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 8...
#
# Recommendations for your picks:
#
# Pick 8:
#   1. A.J. Brown (WR) - Q-value: 55.45, ADP: 10.20
#   2. Puka Nacua (WR) - Q-value: 55.40, ADP: 12.40
#   3. Bijan Robinson (RB) - Q-value: 54.60, ADP: 6.00
#   4. Jonathan Taylor (RB) - Q-value: 54.52, ADP: 11.20
#   5. Marvin Harrison Jr. (WR) - Q-value: 52.93, ADP: 18.00
#
# Pick 17:
#   1. Jalen Hurts (QB) - Q-value: 73.89, ADP: 31.80
#   2. Travis Kelce (TE) - Q-value: 51.06, ADP: 23.40
#   3. Davante Adams (WR) - Q-value: 50.54, ADP: 18.40
#   4. Travis Etienne (RB) - Q-value: 50.09, ADP: 18.20
#   5. Derrick Henry (RB) - Q-value: 49.60, ADP: 18.80
#
# Pick 32:
#   1. DeVonta Smith (WR) - Q-value: 46.65, ADP: 43.40
#   2. Stefon Diggs (WR) - Q-value: 42.53, ADP: 37.80
#   3. DJ Moore (WR) - Q-value: 42.30, ADP: 43.00
#   4. DK Metcalf (WR) - Q-value: 42.01, ADP: 42.20
#   5. Jaylen Waddle (WR) - Q-value: 41.83, ADP: 40.80
#
# Pick 41:
#   1. Zay Flowers (WR) - Q-value: 42.46, ADP: 57.80
#   2. Trey McBride (TE) - Q-value: 40.61, ADP: 46.60
#   3. Tee Higgins (WR) - Q-value: 40.00, ADP: 58.40
#   4. Jaylen Waddle (WR) - Q-value: 37.78, ADP: 40.80
#   5. Mark Andrews (TE) - Q-value: 36.90, ADP: 43.60
#
# Pick 56:
#   1. James Conner (RB) - Q-value: 42.07, ADP: 60.40
#   2. Aaron Jones (RB) - Q-value: 40.65, ADP: 59.80
#   3. Zamir White (RB) - Q-value: 40.15, ADP: 64.80
#   4. Evan Engram (TE) - Q-value: 39.05, ADP: 65.60
#   5. David Montgomery (RB) - Q-value: 38.57, ADP: 64.20
#
# Pick 65:
#   1. Evan Engram (TE) - Q-value: 39.05, ADP: 65.60
#   2. Rhamondre Stevenson (RB) - Q-value: 38.69, ADP: 65.20
#   3. David Montgomery (RB) - Q-value: 38.57, ADP: 64.20
#   4. Raheem Mostert (RB) - Q-value: 38.31, ADP: 76.20
#   5. David Njoku (TE) - Q-value: 37.22, ADP: 82.40
#
# Pick 80:
#   1. Nick Chubb (RB) - Q-value: 26.87, ADP: 90.60
#   2. Austin Ekeler (RB) - Q-value: 26.62, ADP: 89.80
#   3. Brian Robinson Jr. (RB) - Q-value: 26.28, ADP: 97.40
#   4. Zack Moss (RB) - Q-value: 25.94, ADP: 89.00
#   5. Javonte Williams (RB) - Q-value: 25.43, ADP: 97.20
#
# Pick 89:
#   1. Marquise Brown (WR) - Q-value: 22.19, ADP: 90.00
#   2. Diontae Johnson (WR) - Q-value: 21.57, ADP: 91.20
#   3. Austin Ekeler (RB) - Q-value: 21.42, ADP: 89.80
#   4. DeAndre Hopkins (WR) - Q-value: 21.20, ADP: 98.80
#   5. Ladd McConkey (WR) - Q-value: 21.12, ADP: 100.00
#
# Pick 104:
#   1. Christian Watson (WR) - Q-value: 12.84, ADP: 102.40
#   2. Rome Odunze (WR) - Q-value: 12.67, ADP: 104.00
#   3. Ezekiel Elliott (RB) - Q-value: 11.79, ADP: 108.40
#   4. Dallas Goedert (TE) - Q-value: 11.65, ADP: 112.40
#   5. Gus Edwards (RB) - Q-value: 11.59, ADP: 112.20
#
# Pick 113:
#   1. Tyler Lockett (WR) - Q-value: 8.40, ADP: 131.20
#   2. Zach Charbonnet (RB) - Q-value: 8.20, ADP: 132.20
#   3. Cole Kmet (TE) - Q-value: 8.11, ADP: 138.20
#   4. Blake Corum (RB) - Q-value: 6.87, ADP: 123.20
#   5. Curtis Samuel (WR) - Q-value: 6.75, ADP: 136.20
#
# Pick 128:
#   1. J.K. Dobbins (RB) - Q-value: 8.76, ADP: 133.60
#   2. Cole Kmet (TE) - Q-value: 7.69, ADP: 138.20
#   3. Romeo Doubs (WR) - Q-value: 6.79, ADP: 142.60
#   4. Brandin Cooks (WR) - Q-value: 5.20, ADP: 160.60
#   5. Curtis Samuel (WR) - Q-value: 2.55, ADP: 136.20
#
# Pick 137:
#   1. Deshaun Watson (QB) - Q-value: 6.19, ADP: 168.40
#   2. Brandin Cooks (WR) - Q-value: 5.05, ADP: 160.60
#   3. Rico Dowdle (RB) - Q-value: 4.80, ADP: 159.60
#   4. Baker Mayfield (QB) - Q-value: 4.46, ADP: 166.60
#   5. Luke Musgrave (TE) - Q-value: 4.07, ADP: 171.80
#
# Pick 152:
#   1. MIA (DST) - Q-value: 16.04, ADP: 141.00
#   2. Ka'imi Fairbairn (K) - Q-value: 10.15, ADP: 154.80
#   3. CIN (DST) - Q-value: 6.95, ADP: 165.00
#   4. Evan McPherson (K) - Q-value: 6.35, ADP: 160.40
#   5. Jake Moody (K) - Q-value: 1.45, ADP: 167.60
#
# Pick 161:
#   1. Jake Moody (K) - Q-value: 14.53, ADP: 167.60
#   2. Ka'imi Fairbairn (K) - Q-value: 7.76, ADP: 154.80
#   3. Dustin Hopkins (K) - Q-value: 7.30, ADP: 168.00
#   4. Jaylen Wright (RB) - Q-value: 1.53, ADP: 170.80
#   5. Cameron Dicker (K) - Q-value: 1.31, ADP: 183.20
#
# Pick 176:
#   1. Luke Musgrave (TE) - Q-value: 4.09, ADP: 171.80
#   2. Rashid Shaheed (WR) - Q-value: 3.55, ADP: 174.80
#   3. Isaiah Likely (TE) - Q-value: 2.22, ADP: 190.20
#   4. Jahan Dotson (WR) - Q-value: 2.18, ADP: 187.00
#   5. Hunter Henry (TE) - Q-value: 1.81, ADP: 194.00
#
# Pick 185:
#   1. Roman Wilson (WR) - Q-value: 1.55, ADP: 192.50
#   2. Troy Franklin (WR) - Q-value: 1.13, ADP: 198.80
#   3. Demario Douglas (WR) - Q-value: 1.12, ADP: 201.80
#   4. Quentin Johnston (WR) - Q-value: 1.10, ADP: 198.30
#   5. Tyrone Tracy Jr. (RB) - Q-value: 0.87, ADP: 203.60
#
# Pick 200:
#   1. Rashod Bateman (WR) - Q-value: 0.80, ADP: 219.00
#   2. Tyrone Tracy Jr. (RB) - Q-value: 0.78, ADP: 203.60
#   3. Clyde Edwards-Helaire (RB) - Q-value: 0.77, ADP: 218.00
#   4. Wan'Dale Robinson (WR) - Q-value: 0.70, ADP: 216.50
#   5. Roschon Johnson (RB) - Q-value: 0.70, ADP: 216.30
#
# Pick 209:
#   1. Demarcus Robinson (WR) - Q-value: 0.79, ADP: 251.70
#   2. Roschon Johnson (RB) - Q-value: 0.66, ADP: 216.30
#   3. Kenneth Gainwell (RB) - Q-value: 0.61, ADP: 236.30
#   4. Jamaal Williams (RB) - Q-value: 0.52, ADP: 253.30
#   5. AJ Dillon (RB) - Q-value: 0.45, ADP: 235.30
#
# Your team:
# A.J. Brown (WR) - ADP: 10.20, Projection: 17.22
# Jalen Hurts (QB) - ADP: 31.80, Projection: 26.95
# DeVonta Smith (WR) - ADP: 43.40, Projection: 14.64
# Zay Flowers (WR) - ADP: 57.80, Projection: 13.34
# James Conner (RB) - ADP: 60.40, Projection: 13.28
# Evan Engram (TE) - ADP: 65.60, Projection: 12.09
# Nick Chubb (RB) - ADP: 90.60, Projection: 11.28
# Marquise Brown (WR) - ADP: 90.00, Projection: 11.89
# Christian Watson (WR) - ADP: 102.40, Projection: 11.17
# Tyler Lockett (WR) - ADP: 131.20, Projection: 10.59
# J.K. Dobbins (RB) - ADP: 133.60, Projection: 10.46
# Deshaun Watson (QB) - ADP: 168.40, Projection: 19.75
# MIA (DST) - ADP: 141.00, Projection: 11.66
# Jake Moody (K) - ADP: 167.60, Projection: 8.00
# Luke Musgrave (TE) - ADP: 171.80, Projection: 8.38
# Roman Wilson (WR) - ADP: 192.50, Projection: 7.78
# Rashod Bateman (WR) - ADP: 219.00, Projection: 7.96
# Demarcus Robinson (WR) - ADP: 251.70, Projection: 7.93
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 6, 'WR': 7, 'TE': 1, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 9, 'WR': 3, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 214.63
# Team 2: 217.11
# Team 3: 219.29
# Team 4: 222.37
# Team 5: 214.20
# Team 6: 215.87
# Team 7: 219.15
# Team 8: 224.36
# Team 9: 227.00
# Team 10: 227.08
# Team 11: 197.71
# Team 12: 217.37

# %%
user_position=3
print(f"\nSimulating a draft for a user in position {user_position}...")
user_picks, simulated_teams = assistant.simulate_draft(user_position=user_position)  # 0-based index

print("\nRecommendations for your picks:")
for pick_number, recommendations in user_picks:
    print(f"\nPick {pick_number}:")
    for i, (player, q_value) in enumerate(recommendations, 1):
        print(f"  {i}. {player['player']} ({player['pos']}) - Q-value: {q_value:.2f}, ADP: {player['ADP']:.2f}")

print("\nYour team:")
for player in simulated_teams[user_position]:  # user_position is 2 (0-based index)
    print(f"{player['player']} ({player['pos']}) - ADP: {player['ADP']:.2f}, Projection: {player['ppr_projection']:.2f}")

# Analyze position distribution for all teams
def analyze_team(team):
    positions = {pos: 0 for pos in assistant.positions.keys()}
    for player in team:
        positions[player['pos']] += 1
    return positions

print("\nPosition distribution for all teams:")
for i, team in enumerate(simulated_teams):
    positions = analyze_team(team)
    print(f"Team {i+1}: {positions}")

# Calculate and print total projected points for each team
print("\nTotal projected points for each team:")
for i, team in enumerate(simulated_teams):
    total_points = sum(player['ppr_projection'] for player in team)
    print(f"Team {i+1}: {total_points:.2f}")
# Out:
# Simulating a draft for a user in position 3...
#
# Recommendations for your picks:
#
# Pick 4:
#   1. Christian McCaffrey (RB) - Q-value: 332.64, ADP: 1.00
#   2. Saquon Barkley (RB) - Q-value: 327.68, ADP: 10.40
#   3. Bijan Robinson (RB) - Q-value: 327.02, ADP: 6.00
#   4. Amon-Ra St. Brown (WR) - Q-value: 321.46, ADP: 6.80
#   5. Jonathan Taylor (RB) - Q-value: 320.97, ADP: 11.20
#
# Pick 21:
#   1. Jalen Hurts (QB) - Q-value: 291.61, ADP: 31.80
#   2. Josh Allen (QB) - Q-value: 289.89, ADP: 26.20
#   3. Patrick Mahomes (QB) - Q-value: 285.09, ADP: 29.60
#   4. Lamar Jackson (QB) - Q-value: 283.11, ADP: 37.60
#   5. Chris Olave (WR) - Q-value: 283.03, ADP: 23.40
#
# Pick 28:
#   1. Cooper Kupp (WR) - Q-value: 241.04, ADP: 38.20
#   2. Mike Evans (WR) - Q-value: 240.71, ADP: 30.80
#   3. Brandon Aiyuk (WR) - Q-value: 240.35, ADP: 32.80
#   4. DeVonta Smith (WR) - Q-value: 239.97, ADP: 43.40
#   5. Nico Collins (WR) - Q-value: 239.75, ADP: 32.80
#
# Pick 45:
#   1. DJ Moore (WR) - Q-value: 214.51, ADP: 43.00
#   2. DK Metcalf (WR) - Q-value: 210.76, ADP: 42.20
#   3. Amari Cooper (WR) - Q-value: 209.93, ADP: 55.60
#   4. Zay Flowers (WR) - Q-value: 209.26, ADP: 57.80
#   5. George Pickens (WR) - Q-value: 208.42, ADP: 59.80
#
# Pick 52:
#   1. James Conner (RB) - Q-value: 179.47, ADP: 60.40
#   2. Aaron Jones (RB) - Q-value: 178.14, ADP: 59.80
#   3. Trey McBride (TE) - Q-value: 177.61, ADP: 46.60
#   4. Amari Cooper (WR) - Q-value: 177.21, ADP: 55.60
#   5. Zamir White (RB) - Q-value: 176.39, ADP: 64.80
#
# Pick 69:
#   1. Christian Kirk (WR) - Q-value: 148.95, ADP: 71.20
#   2. Chris Godwin (WR) - Q-value: 147.88, ADP: 76.00
#   3. Calvin Ridley (WR) - Q-value: 147.70, ADP: 75.20
#   4. Terry McLaurin (WR) - Q-value: 146.33, ADP: 74.80
#   5. Jayden Reed (WR) - Q-value: 145.69, ADP: 83.20
#
# Pick 76:
#   1. David Njoku (TE) - Q-value: 119.57, ADP: 82.40
#   2. Jake Ferguson (TE) - Q-value: 117.98, ADP: 87.60
#   3. Rashee Rice (WR) - Q-value: 111.88, ADP: 85.20
#   4. Jayden Reed (WR) - Q-value: 111.85, ADP: 83.20
#   5. Tony Pollard (RB) - Q-value: 111.52, ADP: 82.00
#
# Pick 93:
#   1. Rashee Rice (WR) - Q-value: 98.46, ADP: 85.20
#   2. Austin Ekeler (RB) - Q-value: 97.59, ADP: 89.80
#   3. DeAndre Hopkins (WR) - Q-value: 96.46, ADP: 98.80
#   4. Brian Robinson Jr. (RB) - Q-value: 96.45, ADP: 97.40
#   5. Ladd McConkey (WR) - Q-value: 96.38, ADP: 100.00
#
# Pick 100:
#   1. Brian Robinson Jr. (RB) - Q-value: 83.79, ADP: 97.40
#   2. Devin Singletary (RB) - Q-value: 80.65, ADP: 98.60
#   3. Tyjae Spears (RB) - Q-value: 80.17, ADP: 103.20
#   4. Ezekiel Elliott (RB) - Q-value: 78.97, ADP: 108.40
#   5. Chase Brown (RB) - Q-value: 78.94, ADP: 120.80
#
# Pick 117:
#   1. Chase Brown (RB) - Q-value: 74.15, ADP: 120.80
#   2. Trey Benson (RB) - Q-value: 73.88, ADP: 121.80
#   3. Blake Corum (RB) - Q-value: 73.67, ADP: 123.20
#   4. Jerome Ford (RB) - Q-value: 73.58, ADP: 124.60
#   5. J.K. Dobbins (RB) - Q-value: 73.23, ADP: 133.60
#
# Pick 124:
#   1. Brian Thomas Jr. (WR) - Q-value: 71.54, ADP: 124.00
#   2. Tyler Lockett (WR) - Q-value: 71.10, ADP: 131.20
#   3. Jared Goff (QB) - Q-value: 69.67, ADP: 118.00
#   4. Caleb Williams (QB) - Q-value: 69.66, ADP: 117.80
#   5. Curtis Samuel (WR) - Q-value: 69.01, ADP: 136.20
#
# Pick 141:
#   1. Kirk Cousins (QB) - Q-value: 66.25, ADP: 146.00
#   2. Matthew Stafford (QB) - Q-value: 65.61, ADP: 151.00
#   3. Baker Mayfield (QB) - Q-value: 64.16, ADP: 166.60
#   4. Deshaun Watson (QB) - Q-value: 63.88, ADP: 168.40
#   5. Pat Freiermuth (TE) - Q-value: 57.55, ADP: 136.80
#
# Pick 148:
#   1. KC (DST) - Q-value: 56.83, ADP: 140.00
#   2. MIA (DST) - Q-value: 54.67, ADP: 141.00
#   3. CIN (DST) - Q-value: 49.02, ADP: 165.00
#   4. Ka'imi Fairbairn (K) - Q-value: 48.10, ADP: 154.80
#   5. Evan McPherson (K) - Q-value: 46.85, ADP: 160.40
#
# Pick 165:
#   1. Jake Moody (K) - Q-value: 28.62, ADP: 167.60
#   2. Greg Zuerlein (K) - Q-value: 27.14, ADP: 183.30
#   3. Cameron Dicker (K) - Q-value: 26.97, ADP: 183.20
#   4. Chris Boswell (K) - Q-value: 22.70, ADP: 186.50
#   5. Adam Thielen (WR) - Q-value: 21.74, ADP: 170.80
#
# Pick 172:
#   1. Rashid Shaheed (WR) - Q-value: 10.56, ADP: 174.80
#   2. Adam Thielen (WR) - Q-value: 10.44, ADP: 170.80
#   3. Adonai Mitchell (WR) - Q-value: 9.31, ADP: 172.20
#   4. Isaiah Likely (TE) - Q-value: 7.27, ADP: 190.20
#   5. Josh Downs (WR) - Q-value: 7.17, ADP: 184.00
#
# Pick 189:
#   1. Ricky Pearsall (WR) - Q-value: 3.27, ADP: 191.60
#   2. Tyler Conklin (TE) - Q-value: 2.85, ADP: 204.80
#   3. Demario Douglas (WR) - Q-value: 2.84, ADP: 201.80
#   4. Chigoziem Okonkwo (TE) - Q-value: 2.79, ADP: 207.00
#   5. Jermaine Burton (WR) - Q-value: 2.74, ADP: 208.50
#
# Pick 196:
#   1. Chigoziem Okonkwo (TE) - Q-value: 1.96, ADP: 207.00
#   2. Ben Sinnott (TE) - Q-value: 1.92, ADP: 220.80
#   3. Tyler Conklin (TE) - Q-value: 1.92, ADP: 204.80
#   4. Cade Otton (TE) - Q-value: 1.81, ADP: 216.50
#   5. Odell Beckham Jr. (WR) - Q-value: 1.68, ADP: 210.00
#
# Pick 213:
#   1. D'Onta Foreman (RB) - Q-value: 0.89, ADP: 242.50
#   2. Demarcus Robinson (WR) - Q-value: 0.79, ADP: 251.70
#   3. Kenneth Gainwell (RB) - Q-value: 0.79, ADP: 236.30
#   4. Clyde Edwards-Helaire (RB) - Q-value: 0.77, ADP: 218.00
#   5. Miles Sanders (RB) - Q-value: 0.67, ADP: 252.00
#
# Your team:
# Christian McCaffrey (RB) - ADP: 1.00, Projection: 21.86
# Jalen Hurts (QB) - ADP: 31.80, Projection: 26.95
# Cooper Kupp (WR) - ADP: 38.20, Projection: 14.66
# DJ Moore (WR) - ADP: 43.00, Projection: 14.29
# James Conner (RB) - ADP: 60.40, Projection: 13.28
# Christian Kirk (WR) - ADP: 71.20, Projection: 12.61
# David Njoku (TE) - ADP: 82.40, Projection: 12.02
# Rashee Rice (WR) - ADP: 85.20, Projection: 12.33
# Brian Robinson Jr. (RB) - ADP: 97.40, Projection: 11.35
# Chase Brown (RB) - ADP: 120.80, Projection: 10.36
# Brian Thomas Jr. (WR) - ADP: 124.00, Projection: 10.90
# Kirk Cousins (QB) - ADP: 146.00, Projection: 20.33
# KC (DST) - ADP: 140.00, Projection: 13.21
# Jake Moody (K) - ADP: 167.60, Projection: 8.00
# Rashid Shaheed (WR) - ADP: 174.80, Projection: 10.11
# Ricky Pearsall (WR) - ADP: 191.60, Projection: 6.10
# Chigoziem Okonkwo (TE) - ADP: 207.00, Projection: 7.55
# D'Onta Foreman (RB) - ADP: 242.50, Projection: 8.71
#
# Position distribution for all teams:
# Team 1: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 2: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
# Team 3: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 4: {'QB': 2, 'RB': 5, 'WR': 7, 'TE': 2, 'K': 1, 'DST': 1}
# Team 5: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 6: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 7: {'QB': 2, 'RB': 6, 'WR': 6, 'TE': 2, 'K': 1, 'DST': 1}
# Team 8: {'QB': 2, 'RB': 4, 'WR': 8, 'TE': 2, 'K': 1, 'DST': 1}
# Team 9: {'QB': 2, 'RB': 9, 'WR': 3, 'TE': 2, 'K': 1, 'DST': 1}
# Team 10: {'QB': 2, 'RB': 3, 'WR': 9, 'TE': 2, 'K': 1, 'DST': 1}
# Team 11: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
# Team 12: {'QB': 2, 'RB': 7, 'WR': 5, 'TE': 2, 'K': 1, 'DST': 1}
#
# Total projected points for each team:
# Team 1: 214.80
# Team 2: 213.35
# Team 3: 223.91
# Team 4: 234.62
# Team 5: 217.88
# Team 6: 216.59
# Team 7: 218.64
# Team 8: 218.19
# Team 9: 212.42
# Team 10: 224.36
# Team 11: 208.58
# Team 12: 211.54
